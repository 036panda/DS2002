# %%
# %pip install "pymongo[srv]"==3.11
# %pip install --upgrade pymongo
# Out:
# Collecting pymongo[srv]==3.11
#   Using cached pymongo-3.11.0.tar.gz (771 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymongo[srv]==3.11) (1.16.0)
# Installing collected packages: pymongo
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.10.1
#     Uninstalling pymongo-4.10.1:
#       Successfully uninstalled pymongo-4.10.1
#   DEPRECATION: pymongo is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for pymongo ... done
# Successfully installed pymongo-3.11.0
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pymongo in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (3.11.0)
# Collecting pymongo
#   Using cached pymongo-4.10.1-cp311-cp311-macosx_11_0_arm64.whl (889 kB)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pymongo) (1.16.0)
# Installing collected packages: pymongo
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 3.11.0
#     Uninstalling pymongo-3.11.0:
#       Successfully uninstalled pymongo-3.11.0
# Successfully installed pymongo-4.10.1
#
# [notice] A new release of pip available: 22.3.1 -> 24.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
from pymongo import MongoClient
import pprint

# Replace with your MongoDB Atlas connection string
connection_string = "mongodb+srv://036panda:fzn*ZWs.-S6MYvD@cluster0.lfw9n.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"


# Connect to MongoDB Atlas
client = MongoClient(connection_string)
db = client['sample_mflix']
collection = db['movies']

collection.find_one({'genres': 'Action'})
# Out:
# {'_id': ObjectId('573a1391f29313caabcd8319'),
#  'plot': 'An irresponsible young millionaire changes his tune when he falls for the daughter of a downtown minister.',
#  'genres': ['Action', 'Comedy', 'Romance'],
#  'runtime': 58,
#  'rated': 'PASSED',
#  'cast': ['Harold Lloyd', 'Jobyna Ralston', 'Noah Young', 'Jim Mason'],
#  'num_mflix_comments': 0,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTcxMTEwMTIzNl5BMl5BanBnXkFtZTgwMzYzODYwMjE@._V1_SY1000_SX677_AL_.jpg',
#  'title': "For Heaven's Sake",
#  'fullplot': "The Uptown Boy, J. Harold Manners (Lloyd) is a millionaire playboy who falls for the Downtown Girl, Hope (Ralston) who works in Brother Paul's (Weigel) mission. In order to build up attendance, and win Hope's attention, Harold runs through town causing trouble, and winds up with a crowd chasing him right into the mission. He eventually wins the girl and they marry, but not without some interference from his high-brow friends.",
#  'languages': ['English'],
#  'released': datetime.datetime(1926, 4, 5, 0, 0),
#  'directors': ['Sam Taylor'],
#  'writers': ['Ted Wilde (story)',
#   'John Grey (story)',
#   'Clyde Bruckman (story)',
#   'Ralph Spence (titles)'],
#  'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#  'lastupdated': '2015-08-19 00:35:01.953000000',
#  'year': 1926,
#  'imdb': {'rating': 7.6, 'votes': 918, 'id': 16895},
#  'countries': ['USA'],
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 87, 'meter': 92},
#   'production': 'Paramount Studios',
#   'lastUpdated': datetime.datetime(2015, 7, 6, 18, 7, 59)}}

# %% [markdown]
# Exercise 1: Basic Searching and Filtering
#
# **Objective:** Learn how to search for and filter documents in the MongoDB collection.
#
# **Tasks:**
# 1. Write a query to find the first movie that has the genre "Action".
# 2. Write a query to find all movies released after the year 2000 (Return the first 5 results).
# 3. Write a query to find all movies where the IMDb rating is greater than 8.5 (Return the
# first 5 results).
# 4. Write a query to find all movies where the genre contains both "Action" and "Adventure".
#
# **Example Code**:
# action_movie = collection.find_one({"genres": "Action"})
# movies_after_2000 = collection.find({"year": {"$gt": 2000}}).limit(5)
# high_rated_movies = collection.find({"imdb.rating": {"$gt": 8.5}}).limit(5)
# action_adventure_movies = collection.find({"genres": {"$all": ["Action",
# "Adventure"]}}).limit(5

# %%
action_movies = collection.find_one({"genres": "Action"})
action_movies
# Out:
# {'_id': ObjectId('573a1391f29313caabcd8319'),
#  'plot': 'An irresponsible young millionaire changes his tune when he falls for the daughter of a downtown minister.',
#  'genres': ['Action', 'Comedy', 'Romance'],
#  'runtime': 58,
#  'rated': 'PASSED',
#  'cast': ['Harold Lloyd', 'Jobyna Ralston', 'Noah Young', 'Jim Mason'],
#  'num_mflix_comments': 0,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTcxMTEwMTIzNl5BMl5BanBnXkFtZTgwMzYzODYwMjE@._V1_SY1000_SX677_AL_.jpg',
#  'title': "For Heaven's Sake",
#  'fullplot': "The Uptown Boy, J. Harold Manners (Lloyd) is a millionaire playboy who falls for the Downtown Girl, Hope (Ralston) who works in Brother Paul's (Weigel) mission. In order to build up attendance, and win Hope's attention, Harold runs through town causing trouble, and winds up with a crowd chasing him right into the mission. He eventually wins the girl and they marry, but not without some interference from his high-brow friends.",
#  'languages': ['English'],
#  'released': datetime.datetime(1926, 4, 5, 0, 0),
#  'directors': ['Sam Taylor'],
#  'writers': ['Ted Wilde (story)',
#   'John Grey (story)',
#   'Clyde Bruckman (story)',
#   'Ralph Spence (titles)'],
#  'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#  'lastupdated': '2015-08-19 00:35:01.953000000',
#  'year': 1926,
#  'imdb': {'rating': 7.6, 'votes': 918, 'id': 16895},
#  'countries': ['USA'],
#  'type': 'movie',
#  'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 87, 'meter': 92},
#   'production': 'Paramount Studios',
#   'lastUpdated': datetime.datetime(2015, 7, 6, 18, 7, 59)}}

# %%
movies_after_2000 = collection.find({"year": {"$gt": 2000}}).limit(5)
for movie in movies_after_2000:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1393f29313caabcdcb42'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 1 Oscar. Another 1 win & 4 nominations.',
#             'wins': 2},
#  'cast': ['Meg Ryan', 'Hugh Jackman', 'Liev Schreiber', 'Breckin Meyer'],
#  'countries': ['USA'],
#  'directors': ['James Mangold'],
#  'fullplot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#              'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#              'space near the Brooklyn Bridge where there is a gap in time. He '
#              'goes back to the 19th Century and takes pictures of the place. '
#              "Leopold -- a man living in the 1870s -- is puzzled by Stuart's "
#              'tiny camera, follows him back through the gap, and they both '
#              'ended up in the present day. Leopold is clueless about his new '
#              'surroundings. He gets help and insight from Charlie who thinks '
#              'that Leopold is an actor who is always in character. Leopold is '
#              'a highly intelligent man and tries his best to learn and even '
#              'improve the modern conveniences that he encounters.',
#  'genres': ['Comedy', 'Fantasy', 'Romance'],
#  'imdb': {'id': 35423, 'rating': 6.3, 'votes': 59951},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-08-31 00:19:09.717000000',
#  'metacritic': 44,
#  'num_mflix_comments': 0,
#  'plot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#          'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#          'space near the Brooklyn Bridge where there is a gap in time....',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNmNlN2VlOTctYTdhMS00NzUxLTg0ZGMtYWE2ZTJmMThlMTk2XkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 12, 25, 0, 0),
#  'runtime': 118,
#  'title': 'Kate & Leopold',
#  'tomatoes': {'boxOffice': '$47.1M',
#               'consensus': 'Though Jackman charms, Kate and Leopold is bland '
#                            'and predictable, and the time travel scenario '
#                            'lacks inner logic.',
#               'critic': {'meter': 50, 'numReviews': 126, 'rating': 5.3},
#               'dvd': datetime.datetime(2002, 6, 11, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 8, 22, 18, 53, 25),
#               'production': 'Miramax Films',
#               'rotten': 63,
#               'viewer': {'meter': 62, 'numReviews': 189426, 'rating': 3.0},
#               'website': 'http://www.kateandleopold-themovie.com'},
#  'type': 'movie',
#  'writers': ['Steven Rogers (story)',
#              'James Mangold (screenplay)',
#              'Steven Rogers (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a1398f29313caabceb1fe'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Crispin Glover', 'Vanessa Redgrave', 'John Hurt', 'Margot Kidder'],
#  'countries': ['USA', 'Poland', 'Russia'],
#  'directors': ['Menahem Golan'],
#  'fullplot': "A modern day adaptation of Dostoyevsky's classic novel about a "
#              'young student who is forever haunted by the murder he has '
#              'committed.',
#  'genres': ['Drama'],
#  'imdb': {'id': 96056, 'rating': 6.4, 'votes': 463},
#  'languages': ['English', 'Polish'],
#  'lastupdated': '2015-08-13 00:34:02.303000000',
#  'num_mflix_comments': 0,
#  'plot': "A modern day adaptation of Dostoyevsky's classic novel about a young "
#          'student who is forever haunted by the murder he has committed.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTI3MDQ2MzEyOV5BMl5BanBnXkFtZTcwNzEwODUzMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2002, 6, 1, 0, 0),
#  'runtime': 126,
#  'title': 'Crime and Punishment',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 22, 18, 45, 10),
#               'viewer': {'numReviews': 0, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Fyodor Dostoevsky (novel)',
#              'Menahem Golan (adaptation)',
#              'Menahem Golan (screenplay)'],
#  'year': 2002}
# {'_id': ObjectId('573a139af29313caabcf0718'),
#  'awards': {'nominations': 8, 'text': '1 win & 8 nominations.', 'wins': 1},
#  'cast': ['Mariah Carey', 'Max Beesley', 'Da Brat', 'Tia Texada'],
#  'countries': ['USA'],
#  'directors': ['Vondie Curtis-Hall'],
#  'fullplot': 'Billie Frank is a shy, young multiracial girl who is sent away '
#              'by her alcoholic mother at a very early age. At an orphanage, '
#              'she befriends Louise and Roxanne. Flash forward to 1983. Billie '
#              'and her friends are spotted by a record producer, Timothy '
#              'Walker, who wants them to sing backup for his latest pop-music '
#              "discovery. But when super DJ Julian Dice hears Billie's "
#              'incredible voice, he makes a shady deal with Timothy to get her '
#              'out of that dead-end situation. Soon, Billie and Dice are making '
#              'hits inside the studio, and falling in love outside of it. '
#              'Eventually, the pressure of her newfound celebrity puts too '
#              'heavy a strain on Billie, forcing her to decide what it is she '
#              'really wants from Dice, and what she wants for herself.',
#  'genres': ['Drama', 'Music', 'Romance'],
#  'imdb': {'id': 118589, 'rating': 2.1, 'votes': 18840},
#  'languages': ['English'],
#  'lastupdated': '2015-08-21 00:47:31.610000000',
#  'metacritic': 14,
#  'num_mflix_comments': 0,
#  'plot': 'A young singer dates a disc jockey who helps her get into the music '
#          'business, but their relationship become complicated as she ascends '
#          'to super stardom.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMGJkN2IxNTYtZDE1OS00MWJhLWFhNzItNTZkMjM4OGUzMTE2L2ltYWdlXkEyXkFqcGdeQXVyNTg3MTc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 9, 21, 0, 0),
#  'runtime': 104,
#  'title': 'Glitter',
#  'tomatoes': {'boxOffice': '$3.9M',
#               'consensus': 'Glitter is a hodgepodge of movie cliches and bad '
#                            "acting that's sure to generate unintentional "
#                            'laughs. Unfortunately, the movie is not bad enough '
#                            'to be good.',
#               'critic': {'meter': 7, 'numReviews': 87, 'rating': 2.8},
#               'dvd': datetime.datetime(2002, 1, 15, 0, 0),
#               'fresh': 6,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 18, 37, 3),
#               'production': '20th Century Fox',
#               'rotten': 81,
#               'viewer': {'meter': 45, 'numReviews': 44284, 'rating': 2.1},
#               'website': 'http://216.133.243.94'},
#  'type': 'movie',
#  'writers': ['Cheryl L. West (story)', 'Kate Lanier (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a139af29313caabcf0809'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Marcelo Games', 'Marc Pitman', 'Leslie Orr', 'Maureen Allisse'],
#  'countries': ['USA'],
#  'directors': ['Jim Van Bebber'],
#  'fullplot': 'If you think you know the story of the Manson Family, you are '
#              'dead wrong. On a ranch outside of Los Angeles, the dream of the '
#              '"Love Generation" is transforming into something evil. What was '
#              'once an oasis of free love and acid trips has become ground zero '
#              "for a madman's paranoid visions. An average group of kids, the "
#              '"Family," become engulfed in a delusional world where torment '
#              'and slaughter are considered the path to righteousness.Director '
#              'Jim VanBebber (Deadbeat at Dawn) delivers a dizzying, rapid-fire '
#              'vision of the sex and violence that unifies the misguided group, '
#              'a group hell-bent on executing the brutal vision of its leader, '
#              "Charles Manson. You've seen the story through the eyes of the "
#              'law. Now witness it through the eyes of THE MANSOSN FAMILY.',
#  'genres': ['Crime', 'Drama', 'History'],
#  'imdb': {'id': 118840, 'rating': 5.5, 'votes': 2565},
#  'languages': ['English'],
#  'lastupdated': '2015-09-03 00:41:23.867000000',
#  'metacritic': 56,
#  'num_mflix_comments': 0,
#  'plot': 'If you think you know the story of the Manson Family, you are dead '
#          'wrong. On a ranch outside of Los Angeles, the dream of the "Love '
#          'Generation" is transforming into something evil. What was...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTk1NDIzMjY3M15BMl5BanBnXkFtZTcwODE2ODYyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2004, 7, 23, 0, 0),
#  'runtime': 95,
#  'title': 'The Manson Family',
#  'tomatoes': {'critic': {'meter': 68, 'numReviews': 31, 'rating': 6.0},
#               'dvd': datetime.datetime(2005, 4, 26, 0, 0),
#               'fresh': 21,
#               'lastUpdated': datetime.datetime(2015, 7, 20, 18, 38, 35),
#               'production': 'Blue Underground',
#               'rotten': 10,
#               'viewer': {'meter': 48, 'numReviews': 7479, 'rating': 3.0},
#               'website': 'http://www2.themansonfamilymovie.com/'},
#  'type': 'movie',
#  'writers': ['Jim Van Bebber'],
#  'year': 2003}
# {'_id': ObjectId('573a139af29313caabcf0ec0'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 1 Oscar. Another 1 win & 4 nominations.',
#             'wins': 2},
#  'cast': ['Meg Ryan', 'Hugh Jackman', 'Liev Schreiber', 'Breckin Meyer'],
#  'countries': ['USA'],
#  'directors': ['James Mangold'],
#  'fullplot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#              'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#              'space near the Brooklyn Bridge where there is a gap in time. He '
#              'goes back to the 19th Century and takes pictures of the place. '
#              "Leopold -- a man living in the 1870s -- is puzzled by Stuart's "
#              'tiny camera, follows him back through the gap, and they both '
#              'ended up in the present day. Leopold is clueless about his new '
#              'surroundings. He gets help and insight from Charlie who thinks '
#              'that Leopold is an actor who is always in character. Leopold is '
#              'a highly intelligent man and tries his best to learn and even '
#              'improve the modern conveniences that he encounters.',
#  'genres': ['Comedy', 'Fantasy', 'Romance'],
#  'imdb': {'id': 35423, 'rating': 6.3, 'votes': 59924},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-08-29 07:39:50.323000000',
#  'metacritic': 44,
#  'num_mflix_comments': 0,
#  'plot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#          'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#          'space near the Brooklyn Bridge where there is a gap in time....',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNmNlN2VlOTctYTdhMS00NzUxLTg0ZGMtYWE2ZTJmMThlMTk2XkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 12, 25, 0, 0),
#  'runtime': 118,
#  'title': 'Kate & Leopold',
#  'tomatoes': {'boxOffice': '$47.1M',
#               'consensus': 'Though Jackman charms, Kate and Leopold is bland '
#                            'and predictable, and the time travel scenario '
#                            'lacks inner logic.',
#               'critic': {'meter': 50, 'numReviews': 126, 'rating': 5.3},
#               'dvd': datetime.datetime(2002, 6, 11, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 8, 22, 18, 53, 25),
#               'production': 'Miramax Films',
#               'rotten': 63,
#               'viewer': {'meter': 62, 'numReviews': 189426, 'rating': 3.0},
#               'website': 'http://www.kateandleopold-themovie.com'},
#  'type': 'movie',
#  'writers': ['Steven Rogers (story)',
#              'James Mangold (screenplay)',
#              'Steven Rogers (screenplay)'],
#  'year': 2001}

# %%
high_rated_movies = collection.find({"imdb.rating": {"$gt": 8.5}}).limit(5)
for movies in high_rated_movies:
    pprint.pprint(movies)
# Out:
# {'_id': ObjectId('573a1391f29313caabcd9600'),
#  'awards': {'nominations': 0, 'text': '3 wins.', 'wins': 3},
#  'cast': ['Virginia Cherrill',
#           'Florence Lee',
#           'Harry Myers',
#           'Al Ernest Garcia'],
#  'countries': ['USA'],
#  'directors': ['Charles Chaplin'],
#  'fullplot': 'A tramp falls in love with a beautiful blind girl. Her family is '
#              "in financial trouble. The tramp's on-and-off friendship with a "
#              "wealthy man allows him to be the girl's benefactor and suitor.",
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 21749, 'rating': 8.6, 'votes': 93912},
#  'languages': ['English'],
#  'lastupdated': '2015-09-06 00:10:05.493000000',
#  'num_mflix_comments': 0,
#  'plot': 'With the aid of a wealthy erratic tippler, a dewy-eyed tramp who has '
#          'fallen in love with a sightless flower girl accumulates money to be '
#          'able to help her medically.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BY2I4MmM1N2EtM2YzOS00OWUzLTkzYzctNDc5NDg2N2IyODJmXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1931, 3, 7, 0, 0),
#  'runtime': 87,
#  'title': 'City Lights',
#  'tomatoes': {'critic': {'meter': 98, 'numReviews': 42, 'rating': 9.0},
#               'dvd': datetime.datetime(2000, 2, 8, 0, 0),
#               'fresh': 41,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 11, 11),
#               'production': 'Twentieth Century Fox Home Entertainment',
#               'rotten': 1,
#               'viewer': {'meter': 96, 'numReviews': 26133, 'rating': 4.4}},
#  'type': 'movie',
#  'writers': ['Charles Chaplin'],
#  'year': 1931}
# {'_id': ObjectId('573a1392f29313caabcdae3d'),
#  'awards': {'nominations': 1, 'text': '3 wins & 1 nomination.', 'wins': 3},
#  'cast': ['Charles Chaplin',
#           'Paulette Goddard',
#           'Henry Bergman',
#           'Tiny Sandford'],
#  'countries': ['USA'],
#  'directors': ['Charles Chaplin'],
#  'fullplot': "Chaplins last 'silent' film, filled with sound effects, was made "
#              'when everyone else was making talkies. Charlie turns against '
#              'modern society, the machine age, (The use of sound in films ?) '
#              'and progress. Firstly we see him frantically trying to keep up '
#              'with a production line, tightening bolts. He is selected for an '
#              'experiment with an automatic feeding machine, but various '
#              'mishaps leads his boss to believe he has gone mad, and Charlie '
#              'is sent to a mental hospital... When he gets out, he is mistaken '
#              'for a communist while waving a red flag, sent to jail, foils a '
#              'jailbreak, and is let out again. We follow Charlie through many '
#              'more escapades before the film is out.',
#  'genres': ['Comedy', 'Drama'],
#  'imdb': {'id': 27977, 'rating': 8.6, 'votes': 123603},
#  'languages': ['English'],
#  'lastupdated': '2015-09-04 00:06:38.867000000',
#  'metacritic': 96,
#  'num_mflix_comments': 1,
#  'plot': 'The Tramp struggles to live in modern industrial society with the '
#          'help of a young homeless woman.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjJiZjMzYzktNjU0NS00OTkxLWEwYzItYzdhYWJjN2QzMTRlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'G',
#  'released': datetime.datetime(1936, 2, 25, 0, 0),
#  'runtime': 87,
#  'title': 'Modern Times',
#  'tomatoes': {'consensus': 'A slapstick skewering of industrialized America, '
#                            'Modern Times is as politically incisive as it is '
#                            'laugh-out-loud hilarious.',
#               'critic': {'meter': 100, 'numReviews': 53, 'rating': 9.0},
#               'dvd': datetime.datetime(2010, 8, 23, 0, 0),
#               'fresh': 53,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 11, 14),
#               'production': 'United Artists',
#               'rotten': 0,
#               'viewer': {'meter': 95, 'numReviews': 38942, 'rating': 4.3},
#               'website': 'http://www.kino.com/moderntimes'},
#  'type': 'movie',
#  'writers': ['Charles Chaplin'],
#  'year': 1936}
# {'_id': ObjectId('573a1393f29313caabcdc810'),
#  'awards': {'nominations': 6,
#             'text': 'Won 3 Oscars. Another 6 wins & 6 nominations.',
#             'wins': 9},
#  'cast': ['Humphrey Bogart', 'Ingrid Bergman', 'Paul Henreid', 'Claude Rains'],
#  'countries': ['USA'],
#  'directors': ['Michael Curtiz'],
#  'fullplot': 'In World War II Casablanca, Rick Blaine, exiled American and '
#              'former freedom fighter, runs the most popular nightspot in town. '
#              'The cynical lone wolf Blaine comes into the possession of two '
#              'valuable letters of transit. When Nazi Major Strasser arrives in '
#              'Casablanca, the sycophantic police Captain Renault does what he '
#              'can to please him, including detaining a Czechoslovak '
#              "underground leader Victor Laszlo. Much to Rick's surprise, "
#              "Lazslo arrives with Ilsa, Rick's one time love. Rick is very "
#              'bitter towards Ilsa, who ran out on him in Paris, but when he '
#              'learns she had good reason to, they plan to run off together '
#              'again using the letters of transit. Well, that was their '
#              'original plan....',
#  'genres': ['Drama', 'Romance', 'War'],
#  'imdb': {'id': 34583, 'rating': 8.6, 'votes': 354005},
#  'languages': ['English', 'French', 'German', 'Italian'],
#  'lastupdated': '2015-09-04 00:22:54.600000000',
#  'num_mflix_comments': 0,
#  'plot': 'Set in Casablanca, Morocco during the early days of World War II: An '
#          'American expatriate meets a former lover, with unforeseen '
#          'complications.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BY2IzZGY2YmEtYzljNS00NTM5LTgwMzUtMzM1NjQ4NGI0OTk0XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1943, 1, 23, 0, 0),
#  'runtime': 102,
#  'title': 'Casablanca',
#  'tomatoes': {'consensus': "An undisputed masterpiece and perhaps Hollywood's "
#                            'quintessential statement on love and romance, '
#                            'Casablanca has only improved with age, boasting '
#                            'career-defining performances from Humphrey Bogart '
#                            'and Ingrid Bergman.',
#               'critic': {'meter': 97, 'numReviews': 72, 'rating': 9.3},
#               'dvd': datetime.datetime(2000, 2, 15, 0, 0),
#               'fresh': 70,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 2, 29),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 2,
#               'viewer': {'meter': 95, 'numReviews': 354142, 'rating': 4.1},
#               'website': 'http://www.FathomEvents.com'},
#  'type': 'movie',
#  'writers': ['Julius J. Epstein (screenplay)',
#              'Philip G. Epstein (screenplay)',
#              'Howard Koch (screenplay)',
#              'Murray Burnett (play)',
#              'Joan Alison (play)'],
#  'year': 1942}
# {'_id': ObjectId('573a1393f29313caabcdd7d8'),
#  'awards': {'nominations': 0,
#             'text': 'Nominated for 5 Oscars. Another 7 wins.',
#             'wins': 12},
#  'cast': ['James Stewart', 'Donna Reed', 'Lionel Barrymore', 'Thomas Mitchell'],
#  'countries': ['USA'],
#  'directors': ['Frank Capra'],
#  'fullplot': 'George Bailey has spent his entire life giving of himself to the '
#              'people of Bedford Falls. He has always longed to travel but '
#              'never had the opportunity in order to prevent rich skinflint Mr. '
#              'Potter from taking over the entire town. All that prevents him '
#              "from doing so is George's modest building and loan company, "
#              'which was founded by his generous father. But on Christmas Eve, '
#              "George's Uncle Billy loses the business's $8,000 while intending "
#              'to deposit it in the bank. Potter finds the misplaced money and '
#              'hides it from Billy. When the bank examiner discovers the '
#              'shortage later that night, George realizes that he will be held '
#              'responsible and sent to jail and the company will collapse, '
#              'finally allowing Potter to take over the town. Thinking of his '
#              'wife, their young children, and others he loves will be better '
#              'off with him dead, he contemplates suicide. But the prayers of '
#              'his loved ones result in a gentle angel named Clarence coming to '
#              'earth to help George, with the promise of earning his wings. He '
#              'shows George what things would have been like if he had never '
#              'been born. In a nightmarish vision in which the '
#              'Potter-controlled town is sunk in sex and sin, those George '
#              'loves are either dead, ruined, or miserable. He realizes that he '
#              'has touched many people in a positive way and that his life has '
#              'truly been a wonderful one.',
#  'genres': ['Drama', 'Family', 'Fantasy'],
#  'imdb': {'id': 38650, 'rating': 8.6, 'votes': 245046},
#  'languages': ['English'],
#  'lastupdated': '2015-09-05 00:01:34.393000000',
#  'num_mflix_comments': 1,
#  'plot': 'An angel helps a compassionate but despairingly frustrated '
#          'businessman by showing what life would have been like if he never '
#          'existed.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZjc4NDZhZWMtNGEzYS00ZWU2LThlM2ItNTA0YzQ0OTExMTE2XkEyXkFqcGdeQXVyNjUwMzI2NzU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1947, 1, 7, 0, 0),
#  'runtime': 130,
#  'title': "It's a Wonderful Life",
#  'tomatoes': {'consensus': 'The holiday classic to define all holiday '
#                            "classics, It's a Wonderful Life is one of a "
#                            'handful of films worth an annual viewing.',
#               'critic': {'meter': 94, 'numReviews': 68, 'rating': 8.9},
#               'dvd': datetime.datetime(1995, 9, 19, 0, 0),
#               'fresh': 64,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 10, 55),
#               'production': 'Liberty Films',
#               'rotten': 4,
#               'viewer': {'meter': 95, 'numReviews': 215785, 'rating': 4.0}},
#  'type': 'movie',
#  'writers': ['Frances Goodrich (screenplay)',
#              'Albert Hackett (screenplay)',
#              'Frank Capra (screenplay)',
#              'Jo Swerling (additional scenes)',
#              'Philip Van Doren Stern (story)'],
#  'year': 1946}
# {'_id': ObjectId('573a1394f29313caabcdfa00'),
#  'awards': {'nominations': 7,
#             'text': 'Nominated for 4 Oscars. Another 7 wins & 7 nominations.',
#             'wins': 11},
#  'cast': ['James Stewart', 'Grace Kelly', 'Wendell Corey', 'Thelma Ritter'],
#  'countries': ['USA'],
#  'directors': ['Alfred Hitchcock'],
#  'fullplot': 'Professional photographer L.B. "Jeff" Jeffries breaks his leg '
#              'while getting an action shot at an auto race. Confined to his '
#              'New York apartment, he spends his time looking out of the rear '
#              'window observing the neighbors. He begins to suspect that a man '
#              'across the courtyard may have murdered his wife. Jeff enlists '
#              'the help of his high society fashion-consultant girlfriend Lisa '
#              'Freemont and his visiting nurse Stella to investigate.',
#  'genres': ['Mystery', 'Thriller'],
#  'imdb': {'id': 47396, 'rating': 8.6, 'votes': 283273},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:31:57.327000000',
#  'num_mflix_comments': 1,
#  'plot': 'A wheelchair bound photographer spies on his neighbours from his '
#          'apartment window and becomes convinced one of them has committed '
#          'murder.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGUxYWM3M2MtMGM3Mi00ZmRiLWE0NGQtZjE5ODI2OTJhNTU0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'runtime': 112,
#  'title': 'Rear Window',
#  'tomatoes': {'consensus': 'Hitchcock exerted full potential of suspense in '
#                            'this masterpiece.',
#               'critic': {'meter': 100, 'numReviews': 63, 'rating': 8.9},
#               'dvd': datetime.datetime(2001, 3, 6, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 7, 38),
#               'production': 'Paramount Pictures',
#               'rotten': 0,
#               'viewer': {'meter': 95, 'numReviews': 147500, 'rating': 4.2}},
#  'type': 'movie',
#  'writers': ['John Michael Hayes (screenplay)',
#              'Cornell Woolrich (based on the short story by)'],
#  'year': 1954}

# %%
action_adventure_movies = collection.find({"genres": {"$all": ["Action",
"Adventure"]}}).limit(5)
for movies in action_adventure_movies:
    pprint.pprint(movies)
# Out:
# {'_id': ObjectId('573a1392f29313caabcdb585'),
#  'awards': {'nominations': 2,
#             'text': 'Won 3 Oscars. Another 2 wins & 2 nominations.',
#             'wins': 5},
#  'cast': ['Errol Flynn',
#           'Olivia de Havilland',
#           'Basil Rathbone',
#           'Claude Rains'],
#  'countries': ['USA'],
#  'directors': ['Michael Curtiz', 'William Keighley'],
#  'fullplot': 'Sir Robin of Locksley, defender of downtrodden Saxons, runs '
#              'afoul of Norman authority and is forced to turn outlaw. With his '
#              'band of Merry Men, he robs from the rich, gives to the poor and '
#              'still has time to woo the lovely Maid Marian, and foil the cruel '
#              'Sir Guy of Gisbourne, and keep the nefarious Prince John off the '
#              'throne.',
#  'genres': ['Action', 'Adventure', 'Romance'],
#  'imdb': {'id': 29843, 'rating': 8.0, 'votes': 36789},
#  'languages': ['English'],
#  'lastupdated': '2015-08-14 00:11:51.833000000',
#  'metacritic': 97,
#  'num_mflix_comments': 1,
#  'plot': 'When Prince John and the Norman Lords begin oppressing the Saxon '
#          "masses in King Richard's absence, a Saxon lord fights back as the "
#          'outlaw leader of a rebel guerrilla army.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjZjOTU3MTMtYTM5YS00YjZmLThmNmMtODcwOTM1NmRiMWM2XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1938, 5, 14, 0, 0),
#  'runtime': 102,
#  'title': 'The Adventures of Robin Hood',
#  'tomatoes': {'consensus': 'Errol Flynn thrills as the legendary title '
#                            'character, and the film embodies the type of '
#                            'imaginative family adventure tailor-made for the '
#                            'silver screen.',
#               'critic': {'meter': 100, 'numReviews': 44, 'rating': 8.9},
#               'dvd': datetime.datetime(2003, 9, 30, 0, 0),
#               'fresh': 44,
#               'lastUpdated': datetime.datetime(2015, 8, 23, 19, 1, 18),
#               'production': 'Warner Bros.',
#               'rotten': 0,
#               'viewer': {'meter': 89, 'numReviews': 33169, 'rating': 3.7}},
#  'type': 'movie',
#  'writers': ['Norman Reilly Raine (original screenplay: based upon ancient '
#              'Robin Hood legends)',
#              'Seton I. Miller (original screenplay: based upon ancient Robin '
#              'Hood legends)'],
#  'year': 1938}
# {'_id': ObjectId('573a1393f29313caabcdc0f7'),
#  'awards': {'nominations': 0,
#             'text': 'Nominated for 1 Oscar. Another 1 win.',
#             'wins': 2},
#  'cast': ['Tyrone Power',
#           'Linda Darnell',
#           'Basil Rathbone',
#           'Gale Sondergaard'],
#  'countries': ['USA'],
#  'directors': ['Rouben Mamoulian'],
#  'fullplot': 'Around 1820 the son of a California nobleman comes home from '
#              'Spain to find his native land under a villainous dictatorship. '
#              'On the one hand he plays the useless fop, while on the other he '
#              'is the masked avenger Zorro.',
#  'genres': ['Action', 'Adventure', 'Romance'],
#  'imdb': {'id': 32762, 'rating': 7.6, 'votes': 7260},
#  'languages': ['English', 'Spanish'],
#  'lastupdated': '2015-09-04 00:07:34.773000000',
#  'num_mflix_comments': 0,
#  'plot': 'A young aristocrat must masquerade as a fop in order to maintain his '
#          'secret identity of Zorro as he restores justice to early California.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTU2ODc0NzUyMl5BMl5BanBnXkFtZTgwODQ3NTA1MjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1940, 11, 8, 0, 0),
#  'runtime': 94,
#  'title': 'The Mark of Zorro',
#  'tomatoes': {'critic': {'meter': 100, 'numReviews': 9, 'rating': 8.4},
#               'dvd': datetime.datetime(2003, 10, 7, 0, 0),
#               'fresh': 9,
#               'lastUpdated': datetime.datetime(2015, 8, 30, 19, 37, 50),
#               'production': '20th Century Fox',
#               'rotten': 0,
#               'viewer': {'meter': 78, 'numReviews': 8601, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['John Taintor Foote (screenplay)',
#              'Garrett Fort (adaptation)',
#              'Bess Meredyth (adaptation)',
#              'Johnston McCulley (story)'],
#  'year': 1940}
# {'_id': ObjectId('573a1393f29313caabcdc150'),
#  'awards': {'nominations': 5,
#             'text': 'Won 1 Oscar. Another 4 nominations.',
#             'wins': 0},
#  'cast': ['Gary Cooper',
#           'Madeleine Carroll',
#           'Paulette Goddard',
#           'Preston Foster'],
#  'countries': ['USA'],
#  'directors': ['Cecil B. DeMille'],
#  'fullplot': 'Texas Ranger Dusty Rivers ("Isn\'t that a contradiction in '
#              'terms?", another character asks him) travels to Canada in the '
#              '1880s in search of Jacques Corbeau, who is wanted for murder. He '
#              'wanders into the midst of the Riel Rebellion, in which Mètis '
#              '(people of French and Native heritage) and Natives want a '
#              'separate nation. Dusty falls for nurse April Logan, who is also '
#              "loved by Mountie Jim Brett. April's brother is involved with "
#              "Courbeau's daughter Louvette, which leads to trouble during the "
#              'battles between the rebels and the Mounties. Through it all '
#              'Dusty is determined to bring Corbeau back to Texas (and April, '
#              'too, if he can manage it.)',
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 32850, 'rating': 6.7, 'votes': 992},
#  'languages': ['English'],
#  'lastupdated': '2015-08-24 00:44:24.947000000',
#  'num_mflix_comments': 0,
#  'plot': 'Texas Ranger Dusty Rivers ("Isn\'t that a contradiction in terms?", '
#          'another character asks him) travels to Canada in the 1880s in search '
#          'of Jacques Corbeau, who is wanted for murder. He ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZTkzNjI1NTEtMTgyYS00YmY0LWI4ZjItM2E4Y2QwZmRjN2I2XkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1940, 10, 22, 0, 0),
#  'runtime': 126,
#  'title': 'North West Mounted Police',
#  'type': 'movie',
#  'writers': ['Alan Le May (original screen play)',
#              'Jesse Lasky Jr. (original screen play)',
#              'C. Gardner Sullivan (original screen play)'],
#  'year': 1940}
# {'_id': ObjectId('573a1392f29313caabcda755'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Clark Gable', 'Jean Harlow', 'Wallace Beery', 'Lewis Stone'],
#  'countries': ['USA'],
#  'directors': ['Tay Garnett'],
#  'fullplot': 'Dynamic Alan Gaskell captains a ship bound from Hong Kong to '
#              'Singapore. Gaskell tries to turn over a new leaf from his '
#              'hard-drinking lifestyle after becoming attached to a refined '
#              'high class English lady, Sybil Barclay. His former girlfriend '
#              'Dolly is extremely jealous of the budding relationship and tries '
#              'hard to get the Captain back. He is apparently unimpressed with '
#              'her loud, obnoxious, and uncivilized manners, even though she is '
#              'extremely beautiful. After a temporary take over of the ship by '
#              'gold-seeking Asian pirates, Captain Gaskell must deal with the '
#              'fact that Dolly and her drinking pal, Jamesey MacArdle, are '
#              'implicated in the crime.',
#  'genres': ['Action', 'Drama', 'Adventure'],
#  'imdb': {'id': 26205, 'rating': 7.0, 'votes': 1518},
#  'languages': ['English'],
#  'lastupdated': '2015-09-11 00:37:56.387000000',
#  'num_mflix_comments': 2,
#  'plot': 'When earthy Dolly Portland is rejected by Captain Gaskell in favor '
#          'of a socialite, she aids Jamesy McCardle, in league with Malay '
#          'pirates, in his plot to seize his ship.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTgxMDg2MzE3MV5BMl5BanBnXkFtZTgwOTM5MjIyMjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1935, 8, 16, 0, 0),
#  'runtime': 87,
#  'title': 'China Seas',
#  'tomatoes': {'dvd': datetime.datetime(2006, 6, 20, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 7, 23, 18, 45, 51),
#               'production': 'MGM',
#               'viewer': {'meter': 73, 'numReviews': 577, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Jules Furthman (screen play)',
#              'James Kevin McGuinness (screen play)',
#              'Crosbie Garstin (from the book by)'],
#  'year': 1935}
# {'_id': ObjectId('573a1392f29313caabcdacf0'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Buster Crabbe',
#           'Jean Rogers',
#           'Charles Middleton',
#           'Priscilla Lawson'],
#  'countries': ['USA'],
#  'directors': ['Frederick Stephani', 'Ray Taylor'],
#  'fullplot': "A rogue planet is 'rushing madly toward the earth.' Impending "
#              'doom creates worldwide pandemonium. But maverick scientist Dr. '
#              'Zarkov hopes to stay disaster by travelling to the new planet in '
#              'his experimental rocket. Two chance-met strangers, athletic '
#              'Flash Gordon and damsel in distress Dale Arden, go with him. '
#              'Arrived, the trio find Mongo to be a planet of wonders, warring '
#              'factions, and deadly perils, its orbit controlled by Emperor '
#              'Ming who has his own sinister plans for earth. Can our heroes, '
#              'armed only with science and sex appeal, stop him?',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 27623, 'rating': 7.3, 'votes': 1507},
#  'languages': ['English'],
#  'lastupdated': '2015-09-14 12:56:01.370000000',
#  'num_mflix_comments': 0,
#  'plot': 'Three earthlings visit the planet Mongo to thwart the evil schemes '
#          'of Emperor Ming the Merciless.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjA5NDczNjM5Nl5BMl5BanBnXkFtZTgwNzMxMDM1MjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1936, 4, 6, 0, 0),
#  'runtime': 245,
#  'title': 'Flash Gordon',
#  'tomatoes': {'dvd': datetime.datetime(2000, 1, 11, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 7, 34),
#               'viewer': {'meter': 65, 'numReviews': 129, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Alex Raymond (based on the comic strip by)',
#              "Ella O'Neill (screenplay)",
#              'Frederick Stephani (screenplay)',
#              'George H. Plympton (screenplay)',
#              'Basil Dickey (screenplay)'],
#  'year': 1936}

# %% [markdown]
# Exercise 2: Sorting Results
# **Objective:** Learn how to sort query results in MongoDB.
# **Tasks:**
# 1. Write a query to find all movies where the genre is "Comedy" and sort them by IMDb
# rating in descending order (Return the first 5 results).
# 2. Write a query to find all movies where the genre is "Drama" and sort them by release year
# in ascending order (Return the first 5 results).

# %%
sorted_comedy_movies = collection.find({"genres": "Comedy"}).sort("imdb.rating", -
1).limit(5)
for movie in sorted_comedy_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13dcf29313caabdb2dec'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Jennifer Jason Leigh', 'David Thewlis', 'Tom Noonan'],
#  'countries': ['USA'],
#  'directors': ['Duke Johnson', 'Charlie Kaufman'],
#  'fullplot': "Charlie Kaufman's first stop-motion film about a man crippled by "
#              'the mundanity of his life.',
#  'genres': ['Animation', 'Comedy', 'Fantasy'],
#  'imdb': {'id': 2401878, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:00:23.967000000',
#  'num_mflix_comments': 0,
#  'plot': "Charlie Kaufman's first stop-motion film about a man crippled by the "
#          'mundanity of his life.',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 9, 8, 0, 0),
#  'runtime': 90,
#  'title': 'Anomalisa',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 26, 18, 15, 38),
#               'production': 'Walt Disney Pictures International',
#               'viewer': {'numReviews': 12, 'rating': 2.5}},
#  'type': 'movie',
#  'writers': ['Charlie Kaufman'],
#  'year': 2015}
# {'_id': ObjectId('573a13d9f29313caabdaa62d'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Ray Panthaki', 'Vicky McClure', 'Adeel Akhtar', 'Jenny Bede'],
#  'countries': ['UK'],
#  'directors': ['Keri Collins'],
#  'fullplot': 'Two convenience store robbers mess up the crime and end up '
#              'working there for the rest of the night.',
#  'genres': ['Comedy'],
#  'imdb': {'id': 2263210, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-09-14 17:30:41.583000000',
#  'num_mflix_comments': 0,
#  'plot': 'Two convenience store robbers mess up the crime and end up working '
#          'there for the rest of the night.',
#  'released': datetime.datetime(2015, 10, 2, 0, 0),
#  'title': 'Convenience',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 9, 52, 44),
#               'viewer': {'numReviews': 3, 'rating': 4.0},
#               'website': 'http://www.convenience-movie.com'},
#  'type': 'movie',
#  'writers': ['Simon Fantauzzo'],
#  'year': 2015}
# {'_id': ObjectId('573a13dff29313caabdb909e'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Jessie Barr',
#           'Louis Cancelmi',
#           'Margaret Daly',
#           'Caitlin FitzGerald'],
#  'countries': ['USA'],
#  'directors': ["Tom O'Brien"],
#  'fullplot': 'Danny, a commercial editor and documentary filmmaker attempts to '
#              'finish his film, a study on relationship while navigating the '
#              'relationships in his own life. Will he continue to chase the '
#              'unattainable Theresa a hippy new age dancer(Caitlin Fitzgerald) '
#              "or will he finally admit he's in love with his best friend Carla "
#              '(Katherine Waterston) who is in an unfulfilling relationship '
#              'with a political strategist(Gaby Hoffman). Manhattan Romance is '
#              'a funny insightful look at contemporary life in Manhattan. It '
#              'explores new age ideas and open relationship as well as true '
#              'friendship and connection.',
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 2608324, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-28 00:17:01.610000000',
#  'num_mflix_comments': 0,
#  'plot': 'Danny, a commercial editor and documentary filmmaker attempts to '
#          'finish his film, a study on relationship while navigating the '
#          'relationships in his own life. Will he continue to chase the ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjMzODk2MDc0MF5BMl5BanBnXkFtZTgwMTc3NjU4NjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 10, 2, 0, 0),
#  'runtime': 94,
#  'title': 'Manhattan Romance',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 2, 18, 57, 41),
#               'viewer': {'numReviews': 2, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ["Tom O'Brien"],
#  'year': 2015}
# {'_id': ObjectId('573a13def29313caabdb627d'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Gracie Mei Huntsman',
#           'Jon Huntsman',
#           'Jerome A. Cohen',
#           'Chen Guangcheng'],
#  'countries': ['China', 'USA'],
#  'directors': ['Vanessa Hope'],
#  'genres': ['Documentary', 'Comedy', 'History'],
#  'imdb': {'id': 2505376, 'rating': '', 'votes': ''},
#  'languages': ['English', 'Chinese'],
#  'lastupdated': '2015-08-26 01:05:17.383000000',
#  'num_mflix_comments': 1,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAyNzYzNzIyM15BMl5BanBnXkFtZTgwMjA4ODgxNTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 4, 20, 0, 0),
#  'runtime': 90,
#  'title': 'All Eyes and Ears',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 6, 26, 18, 3, 5),
#               'viewer': {'numReviews': 1, 'rating': 1.5}},
#  'type': 'movie',
#  'writers': ['Vanessa Hope'],
#  'year': 2015}
# {'_id': ObjectId('573a13cff29313caabd88f5b'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Halston Sage',
#           'Tye Sheridan',
#           'Patrick Schwarzenegger',
#           'Cloris Leachman'],
#  'countries': ['USA'],
#  'directors': ['Christopher Landon'],
#  'fullplot': 'Three scouts, on the eve of their last camp-out, discover the '
#              'true meaning of friendship when they attempt to save their town '
#              'from a zombie outbreak.',
#  'genres': ['Comedy', 'Horror'],
#  'imdb': {'id': 1727776, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-27 00:00:19.697000000',
#  'num_mflix_comments': 0,
#  'plot': 'Three scouts, on the eve of their last camp-out, discover the true '
#          'meaning of friendship when they attempt to save their town from a '
#          'zombie outbreak.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY4NjczNjE4OV5BMl5BanBnXkFtZTgwODk0MjQ5NjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 10, 30, 0, 0),
#  'runtime': 93,
#  'title': 'Scouts Guide to the Zombie Apocalypse',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 30, 20, 13, 8),
#               'production': 'Paramount Pictures',
#               'viewer': {'numReviews': 91, 'rating': 2.8},
#               'website': 'http://www.scoutsandzombiesmovie.com/'},
#  'type': 'movie',
#  'writers': ['Emi Mochizuki (screenplay)',
#              'Carrie Lee Wilson (screenplay)',
#              'Christopher Landon (screenplay)',
#              'Lona Williams (screenplay)'],
#  'year': 2015}

# %%
sorted_drama_movies = collection.find({"genres": "Drama"}).sort("year", 1).limit(5)
for movie in sorted_drama_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1390f29313caabcd446f'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Frank Powell',
#           'Grace Henderson',
#           'James Kirkwood',
#           'Linda Arvidson'],
#  'countries': ['USA'],
#  'directors': ['D.W. Griffith'],
#  'fullplot': 'A greedy tycoon decides, on a whim, to corner the world market '
#              "in wheat. This doubles the price of bread, forcing the grain's "
#              'producers into charity lines and further into poverty. The film '
#              'continues to contrast the ironic differences between the lives '
#              'of those who work to grow the wheat and the life of the man who '
#              'dabbles in its sale for profit.',
#  'genres': ['Short', 'Drama'],
#  'imdb': {'id': 832, 'rating': 6.6, 'votes': 1375},
#  'languages': ['English'],
#  'lastupdated': '2015-08-13 00:46:30.660000000',
#  'num_mflix_comments': 1,
#  'plot': 'A greedy tycoon decides, on a whim, to corner the world market in '
#          "wheat. This doubles the price of bread, forcing the grain's "
#          'producers into charity lines and further into poverty. The film...',
#  'rated': 'G',
#  'released': datetime.datetime(1909, 12, 13, 0, 0),
#  'runtime': 14,
#  'title': 'A Corner in Wheat',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 5, 11, 18, 36, 53),
#               'viewer': {'meter': 73, 'numReviews': 109, 'rating': 3.6}},
#  'type': 'movie',
#  'year': 1909}
# {'_id': ObjectId('573a1390f29313caabcd4eaf'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Jane Gail', 'Ethel Grandin', 'William H. Turner', 'Matt Moore'],
#  'countries': ['USA'],
#  'directors': ['George Loane Tucker'],
#  'genres': ['Crime', 'Drama'],
#  'imdb': {'id': 3471, 'rating': 6.0, 'votes': 371},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 02:07:14.247000000',
#  'num_mflix_comments': 1,
#  'plot': 'A woman, with the aid of her police officer sweetheart, endeavors to '
#          'uncover the prostitution ring that has kidnapped her sister, and the '
#          'philanthropist who secretly runs it.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYzk0YWQzMGYtYTM5MC00NjM2LWE5YzYtMjgyNDVhZDg1N2YzXkEyXkFqcGdeQXVyMzE0MjY5ODA@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-PG',
#  'released': datetime.datetime(1913, 11, 24, 0, 0),
#  'runtime': 88,
#  'title': 'Traffic in Souls',
#  'tomatoes': {'dvd': datetime.datetime(2008, 8, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 10, 18, 33, 55),
#               'viewer': {'meter': 57, 'numReviews': 85, 'rating': 3.0}},
#  'type': 'movie',
#  'year': 1913}
# {'_id': ObjectId('573a1390f29313caabcd516c'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Stanley Hunt',
#           'Sarah Constance Smith Hunt',
#           'Mrs. George Walkus',
#           "Paddy 'Malid"],
#  'countries': ['USA'],
#  'directors': ['Edward S. Curtis'],
#  'genres': ['Drama', 'History'],
#  'imdb': {'id': 4150, 'rating': 5.8, 'votes': 223},
#  'languages': ['English'],
#  'lastupdated': '2015-09-16 12:11:37.770000000',
#  'num_mflix_comments': 1,
#  'plot': 'Original advertising for the film describes it as a drama of '
#          'primitive life on the shores of the North Pacific...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjE3MjAyNzM5NV5BMl5BanBnXkFtZTgwMjA5OTg5NjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1914, 12, 7, 0, 0),
#  'runtime': 65,
#  'title': 'In the Land of the Head Hunters',
#  'tomatoes': {'dvd': datetime.datetime(2000, 8, 15, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 18, 19, 21, 12),
#               'production': 'World Film Corporation',
#               'viewer': {'meter': 18, 'numReviews': 64, 'rating': 2.7},
#               'website': 'http://www.milestonefilms.com/'},
#  'type': 'movie',
#  'writers': ['Edward S. Curtis (story)'],
#  'year': 1914}
# {'_id': ObjectId('573a1390f29313caabcd587d'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['John McCann', 'James A. Marcus', 'Maggie Weston', 'Harry McCoy'],
#  'countries': ['USA'],
#  'directors': ['Raoul Walsh'],
#  'fullplot': 'At 10 years old, Owens becomes a ragged orphan when his sainted '
#              'mother dies. The Conways, who are next door neighbors, take Owen '
#              'in, but the constant drinking by Jim soon puts Owen on the '
#              'street. By 17, Owen learns that might is right. By 25, Owen is '
#              'the leader of his own gang who spend most of their time gambling '
#              'and drinking. But Marie comes into the gangster area of town and '
#              'everything changes for Owen as he falls for Marie. But he cannot '
#              'tell her so, so he comes to her settlement to find education and '
#              'inspiration. But soon, his old way of life will rise to confront '
#              'him again.',
#  'genres': ['Biography', 'Crime', 'Drama'],
#  'imdb': {'id': 5960, 'rating': 6.8, 'votes': 626},
#  'languages': ['English'],
#  'lastupdated': '2015-08-14 01:28:18.957000000',
#  'num_mflix_comments': 1,
#  'plot': 'At 10 years old, Owens becomes a ragged orphan when his sainted '
#          'mother dies. The Conways, who are next door neighbors, take Owen in, '
#          'but the constant drinking by Jim soon puts Owen on the ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNDkxZGU4NmMtODJlNy00YzA2LTg4ZGMtNGFlNzAyNzcxOTM1XkEyXkFqcGdeQXVyOTM3MjcyMjI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1915, 9, 13, 0, 0),
#  'runtime': 72,
#  'title': 'Regeneration',
#  'tomatoes': {'critic': {'meter': 100, 'numReviews': 5, 'rating': 9.2},
#               'dvd': datetime.datetime(2001, 11, 27, 0, 0),
#               'fresh': 5,
#               'lastUpdated': datetime.datetime(2015, 9, 17, 17, 22, 42),
#               'production': 'Fox Film Corporation',
#               'rotten': 0,
#               'viewer': {'meter': 70, 'numReviews': 395, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Owen Frawley Kildare (book)',
#              'Raoul Walsh (adapted from the book: "My Mamie Rose")',
#              'Carl Harbaugh (adapted from the book: "My Mamie Rose")'],
#  'year': 1915}
# {'_id': ObjectId('573a1390f29313caabcd56df'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['George Beban', 'Clara Williams', 'J. Frank Burke', 'Leo Willis'],
#  'countries': ['USA'],
#  'directors': ['Reginald Barker'],
#  'fullplot': 'An immigrant leaves his sweetheart in Italy to find a better '
#              'life across the sea in the grimy slums of New York. They are '
#              'eventually reunited and marry. But life in New York is hard and '
#              'tragedy tarnishes their dream of a better life in the new world.',
#  'genres': ['Drama'],
#  'imdb': {'id': 5557, 'rating': 6.4, 'votes': 175},
#  'languages': ['English'],
#  'lastupdated': '2015-07-27 00:07:43.230000000',
#  'num_mflix_comments': 0,
#  'plot': 'An immigrant leaves his sweetheart in Italy to find a better life '
#          'across the sea in the grimy slums of New York. They are eventually '
#          'reunited and marry. But life in New York is hard and ...',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1915, 1, 1, 0, 0),
#  'runtime': 78,
#  'title': 'The Italian',
#  'tomatoes': {'dvd': datetime.datetime(2008, 8, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 7, 24, 19, 30, 2),
#               'viewer': {'meter': 60, 'numReviews': 204, 'rating': 4.0}},
#  'type': 'movie',
#  'writers': ['Thomas H. Ince (story)', 'C. Gardner Sullivan (story)'],
#  'year': 1915}

# %% [markdown]
# Exercise 3: Aggregation Pipeline
# **Objective:** Use MongoDB’s aggregation framework to analyze and transform data.
# **Tasks:**
# 1. Write an aggregation pipeline that calculates the average IMDb rating for each genre
# (Return the top 5 genres).
# 2. Write an aggregation pipeline to find the top 5 directors by the average IMDb rating of
# their movies.
# 3. Write an aggregation pipeline to calculate the total number of movies released in each
# year (Sort the results by the year).

# %%
avg_IMBD_rating_by_genre = collection.aggregate([
{"$unwind": "$genres"},
{"$group": {"_id": "$genres", "avg_rating": {"$avg": "$imdb.rating"}}},
{"$sort": {"avg_rating": -1}},
{"$limit": 5}
])


for data in avg_IMBD_rating_by_genre:
    pprint.pprint(data)
# Out:
# {'_id': 'Film-Noir', 'avg_rating': 7.397402597402598}
# {'_id': 'Short', 'avg_rating': 7.377574370709382}
# {'_id': 'Documentary', 'avg_rating': 7.365679824561403}
# {'_id': 'News', 'avg_rating': 7.252272727272728}
# {'_id': 'History', 'avg_rating': 7.1696100917431185}

# %%
top_5_directors = collection.aggregate([
{"$group": {"_id": "$directors", "avg_rating": {"$avg": "$imdb.rating"}}},
{"$sort": {"avg_rating": -1}},
{"$limit": 5}
])

for data in top_5_directors:
    pprint.pprint(data)
# Out:
# {'_id': ['Sara Hirsh Bordo'], 'avg_rating': 9.4}
# {'_id': ['Kevin Derek'], 'avg_rating': 9.3}
# {'_id': ['Michael Benson'], 'avg_rating': 9.0}
# {'_id': ['Slobodan Sijan'], 'avg_rating': 8.95}
# {'_id': ['Sundar C.'], 'avg_rating': 8.9}

# %%
movies_released = collection.aggregate([
{"$group": {"_id": "$year", "total_movies": {"$sum": 1}}},
{"$sort": {"_id": 1}}
])

for data in movies_released:
    pprint.pprint(data)
# Out:
# {'_id': 1896, 'total_movies': 2}
# {'_id': 1903, 'total_movies': 1}
# {'_id': 1909, 'total_movies': 1}
# {'_id': 1911, 'total_movies': 2}
# {'_id': 1913, 'total_movies': 1}
# {'_id': 1914, 'total_movies': 3}
# {'_id': 1915, 'total_movies': 2}
# {'_id': 1916, 'total_movies': 2}
# {'_id': 1917, 'total_movies': 2}
# {'_id': 1918, 'total_movies': 1}
# {'_id': 1919, 'total_movies': 1}
# {'_id': 1920, 'total_movies': 4}
# {'_id': 1921, 'total_movies': 5}
# {'_id': 1922, 'total_movies': 3}
# {'_id': 1923, 'total_movies': 2}
# {'_id': 1924, 'total_movies': 6}
# {'_id': 1925, 'total_movies': 3}
# {'_id': 1926, 'total_movies': 6}
# {'_id': 1927, 'total_movies': 4}
# {'_id': 1928, 'total_movies': 8}
# {'_id': 1929, 'total_movies': 7}
# {'_id': 1930, 'total_movies': 10}
# {'_id': 1931, 'total_movies': 20}
# {'_id': 1932, 'total_movies': 18}
# {'_id': 1933, 'total_movies': 20}
# {'_id': 1934, 'total_movies': 23}
# {'_id': 1935, 'total_movies': 31}
# {'_id': 1936, 'total_movies': 30}
# {'_id': 1937, 'total_movies': 31}
# {'_id': 1938, 'total_movies': 38}
# {'_id': 1939, 'total_movies': 20}
# {'_id': 1940, 'total_movies': 24}
# {'_id': 1941, 'total_movies': 24}
# {'_id': 1942, 'total_movies': 30}
# {'_id': 1943, 'total_movies': 32}
# {'_id': 1944, 'total_movies': 23}
# {'_id': 1945, 'total_movies': 29}
# {'_id': 1946, 'total_movies': 34}
# {'_id': 1947, 'total_movies': 29}
# {'_id': 1948, 'total_movies': 56}
# {'_id': 1949, 'total_movies': 52}
# {'_id': 1950, 'total_movies': 55}
# {'_id': 1951, 'total_movies': 54}
# {'_id': 1952, 'total_movies': 45}
# {'_id': 1953, 'total_movies': 65}
# {'_id': 1954, 'total_movies': 47}
# {'_id': 1955, 'total_movies': 67}
# {'_id': 1956, 'total_movies': 67}
# {'_id': 1957, 'total_movies': 71}
# {'_id': 1958, 'total_movies': 75}
# {'_id': 1959, 'total_movies': 71}
# {'_id': 1960, 'total_movies': 73}
# {'_id': 1961, 'total_movies': 68}
# {'_id': 1962, 'total_movies': 70}
# {'_id': 1963, 'total_movies': 69}
# {'_id': 1964, 'total_movies': 86}
# {'_id': 1965, 'total_movies': 77}
# {'_id': 1966, 'total_movies': 87}
# {'_id': 1967, 'total_movies': 81}
# {'_id': 1968, 'total_movies': 89}
# {'_id': 1969, 'total_movies': 107}
# {'_id': 1970, 'total_movies': 120}
# {'_id': 1971, 'total_movies': 106}
# {'_id': 1972, 'total_movies': 121}
# {'_id': 1973, 'total_movies': 112}
# {'_id': 1974, 'total_movies': 103}
# {'_id': 1975, 'total_movies': 107}
# {'_id': 1976, 'total_movies': 116}
# {'_id': 1977, 'total_movies': 123}
# {'_id': 1978, 'total_movies': 128}
# {'_id': 1979, 'total_movies': 131}
# {'_id': 1980, 'total_movies': 167}
# {'_id': 1981, 'total_movies': 168}
# {'_id': 1982, 'total_movies': 177}
# {'_id': 1983, 'total_movies': 161}
# {'_id': 1984, 'total_movies': 199}
# {'_id': 1985, 'total_movies': 189}
# {'_id': 1986, 'total_movies': 190}
# {'_id': 1987, 'total_movies': 222}
# {'_id': 1988, 'total_movies': 251}
# {'_id': 1989, 'total_movies': 232}
# {'_id': 1990, 'total_movies': 225}
# {'_id': 1991, 'total_movies': 238}
# {'_id': 1992, 'total_movies': 270}
# {'_id': 1993, 'total_movies': 274}
# {'_id': 1994, 'total_movies': 305}
# {'_id': 1995, 'total_movies': 372}
# {'_id': 1996, 'total_movies': 407}
# {'_id': 1997, 'total_movies': 439}
# {'_id': 1998, 'total_movies': 513}
# {'_id': 1999, 'total_movies': 515}
# {'_id': 2000, 'total_movies': 581}
# {'_id': 2001, 'total_movies': 612}
# {'_id': 2002, 'total_movies': 622}
# {'_id': 2003, 'total_movies': 603}
# {'_id': 2004, 'total_movies': 678}
# {'_id': 2005, 'total_movies': 713}
# {'_id': 2006, 'total_movies': 774}
# {'_id': 2007, 'total_movies': 810}
# {'_id': 2008, 'total_movies': 886}
# {'_id': 2009, 'total_movies': 917}
# {'_id': 2010, 'total_movies': 866}
# {'_id': 2011, 'total_movies': 893}
# {'_id': 2012, 'total_movies': 955}
# {'_id': 2013, 'total_movies': 1105}
# {'_id': 2014, 'total_movies': 1073}
# {'_id': 2015, 'total_movies': 480}
# {'_id': 2016, 'total_movies': 1}
# {'_id': '1981è', 'total_movies': 1}
# {'_id': '1986è', 'total_movies': 1}
# {'_id': '1987è', 'total_movies': 1}
# {'_id': '1988è', 'total_movies': 1}
# {'_id': '1994è1998', 'total_movies': 1}
# {'_id': '1995è', 'total_movies': 1}
# {'_id': '1996è', 'total_movies': 1}
# {'_id': '1997è', 'total_movies': 2}
# {'_id': '1999è', 'total_movies': 1}
# {'_id': '2000è', 'total_movies': 1}
# {'_id': '2002è', 'total_movies': 1}
# {'_id': '2003è', 'total_movies': 1}
# {'_id': '2005è', 'total_movies': 2}
# {'_id': '2006è', 'total_movies': 1}
# {'_id': '2006è2007', 'total_movies': 1}
# {'_id': '2006è2012', 'total_movies': 2}
# {'_id': '2007è', 'total_movies': 3}
# {'_id': '2009è', 'total_movies': 2}
# {'_id': '2010è', 'total_movies': 4}
# {'_id': '2011è', 'total_movies': 2}
# {'_id': '2012è', 'total_movies': 3}
# {'_id': '2014è', 'total_movies': 2}

# %% [markdown]
# Exercise 4: Updating and Deleting Documents
# **Objective:** Learn how to update and delete documents in MongoDB.
# **Tasks:**
# 1. Write a query to update the IMDb rating of a movie with the title "The Godfather" to 9.5.
# 2. Write a query to update all movies where the genre is "Horror" and set their IMDb rating
# to 6.0 if it is currently null.
# 3. Write a query to delete all movies that were released before the year 1950.

# %%
collection.update_one({"title": "The Godfather"}, {"$set": {"imdb.rating": 9.3}})
# Out:
# UpdateResult({'n': 1, 'electionId': ObjectId('7fffffff0000000000000120'), 'opTime': {'ts': Timestamp(1728173831, 30), 't': 288}, 'nModified': 1, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1728173831, 31), 'signature': {'hash': b'\xde-b\xa4B#\xeb\x13R\xff=I\xca\xc6\xc1\x80f-\x9f\xfc', 'keyId': 7363326094432272385}}, 'operationTime': Timestamp(1728173831, 30), 'updatedExisting': True}, acknowledged=True)

# %%
collection.update_many({"genres": "Horror", "imdb.rating": {"$exists": False}}, {"$set":
{"imdb.rating": 6.0}})
# Out:
# UpdateResult({'n': 0, 'electionId': ObjectId('7fffffff0000000000000120'), 'opTime': {'ts': Timestamp(1728173859, 26), 't': 288}, 'nModified': 0, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1728173859, 26), 'signature': {'hash': b'\xe8\x85\xce\xc4\xf4w\x92\xed\xe9\x8d\x99j\x84\xd3\xaa\xf1\x1c\xbf}\xeb', 'keyId': 7363326094432272385}}, 'operationTime': Timestamp(1728173859, 26), 'updatedExisting': False}, acknowledged=True)

# %%
collection.delete_many({"year": {"$lt": 1950}})
# Out:
# DeleteResult({'n': 640, 'electionId': ObjectId('7fffffff0000000000000120'), 'opTime': {'ts': Timestamp(1728173889, 21), 't': 288}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1728173889, 31), 'signature': {'hash': b'\x8c>\xbe\x90\xc8\x8c[e\xc3\xa5@\xeb\xcaa\xb0\xaf\xcc\x06z\xcd', 'keyId': 7363326094432272385}}, 'operationTime': Timestamp(1728173889, 21)}, acknowledged=True)

# %% [markdown]
# Exercise 5: Text Search
# **Objective:** Learn how to perform text searches in MongoDB.
# **Tasks:**
# 1. Ensure the title field is indexed for text search in MongoDB and write a query to search
# for movies that contain the word "love" in their title.
# 2. Write a text search query to find movies where the word "war" appears in the title or plot,
# sorted by IMDb rating (Return only the top 5 results).

# %%
love_movies = collection.find({"$text": {"$search": "love"}})
list(love_movies)
# Out:
# [{'_id': ObjectId('573a13a5f29313caabd14e36'),
#   'fullplot': "It's All About Love is the story of two lovers and their attempts to save their relationship in a near-future world on the brink of cosmic collapse. John, and world-famous ice skating star, Elena, are about to sign divorce papers when they realise that, in spite of everything happening around them, their love is worth fighting for. It's All About Love is a fresh take on modern love and future life as two lovers struggle in a conspiracy of epic proportions.",
#   'imdb': {'rating': 5.5, 'votes': 6964, 'id': 273689},
#   'year': 2003,
#   'plot': "It's All About Love is the story of two lovers and their attempts to save their relationship in a near-future world on the brink of cosmic collapse. John, and world-famous ice skating star,...",
#   'genres': ['Drama', 'Thriller', 'Romance'],
#   'rated': 'R',
#   'metacritic': 32,
#   'title': "It's All About Love",
#   'lastupdated': '2015-08-12 00:00:48.250000000',
#   'languages': ['English'],
#   'writers': ['Mogens Rukov', 'Thomas Vinterberg'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.tvropa.com/itsallaboutlove/',
#    'viewer': {'rating': 2.6, 'numReviews': 1292, 'meter': 26},
#    'dvd': datetime.datetime(2005, 9, 27, 0, 0),
#    'critic': {'rating': 3.8, 'numReviews': 29, 'meter': 14},
#    'lastUpdated': datetime.datetime(2015, 8, 6, 20, 15, 18),
#    'rotten': 25,
#    'production': 'Focus Features',
#    'fresh': 4},
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzMzc1MDI3NV5BMl5BanBnXkFtZTcwNDQyMzcyMQ@@._V1_SY1000_SX677_AL_.jpg',
#   'num_mflix_comments': 1,
#   'released': datetime.datetime(2003, 1, 10, 0, 0),
#   'awards': {'wins': 3, 'nominations': 0, 'text': '3 wins.'},
#   'countries': ['Italy',
#    'France',
#    'Canada',
#    'Spain',
#    'USA',
#    'Japan',
#    'Sweden',
#    'UK',
#    'Denmark',
#    'Germany',
#    'Netherlands'],
#   'cast': ['Joaquin Phoenix', 'Claire Danes', 'Sean Penn', 'Douglas Henshall'],
#   'directors': ['Thomas Vinterberg'],
#   'runtime': 104},
#  {'_id': ObjectId('573a13a6f29313caabd19168'),
#   'plot': 'A young woman who is in love with a married doctor becomes dangerous when her attempts to persuade him to leave his wife are unsuccessful. However, when things are seen from his point of view, the real situation becomes clear.',
#   'genres': ['Romance', 'Thriller'],
#   'runtime': 92,
#   'metacritic': 63,
#   'rated': 'PG-13',
#   'cast': ['Audrey Tautou',
#    'Samuel Le Bihan',
#    'Isabelle Carrè',
#    'Sophie Guillemin'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjE0NzcwMjM4Ml5BMl5BanBnXkFtZTcwMjgyMjEyMQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'He Loves Me... He Loves Me Not',
#   'fullplot': 'Angelique, a young student, is in love with a married doctor. We see her attempts to make him leave his pregnant wife, but he does not appear for meetings or finally the booked journey to Florence. Then the movie is turned back to the beginning, and the view changes: We are now following the view of the doctor instead of Angeliques. And things look quite different now...',
#   'languages': ['French'],
#   'released': datetime.datetime(2002, 3, 27, 0, 0),
#   'directors': ['Laetitia Colombani'],
#   'writers': ['Laetitia Colombani', 'Caroline Thivel (collaborating writer)'],
#   'awards': {'wins': 0, 'nominations': 2, 'text': '2 nominations.'},
#   'lastupdated': '2015-09-10 17:15:26.557000000',
#   'year': 2002,
#   'imdb': {'rating': 7.3, 'votes': 15360, 'id': 291579},
#   'countries': ['France'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.helovesmethemovie.com',
#    'viewer': {'rating': 3.8, 'numReviews': 22933, 'meter': 85},
#    'dvd': datetime.datetime(2003, 8, 12, 0, 0),
#    'critic': {'rating': 6.8, 'numReviews': 71, 'meter': 73},
#    'boxOffice': '$0.4M',
#    'consensus': "This romantic thriller puts Tautou's sweetheart Amelie image to good use.",
#    'rotten': 19,
#    'production': 'Samuel Goldwyn Company',
#    'lastUpdated': datetime.datetime(2015, 7, 23, 18, 42, 57),
#    'fresh': 52},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a13d0f29313caabd8b450'),
#   'plot': 'A racially-charged criminal trial and a heart-rending love story converge in this documentary about Richard and Mildred Loving, set during the turbulent Civil Rights era. Long Way Home: The...',
#   'genres': ['Documentary', 'Drama', 'History'],
#   'runtime': 77,
#   'cast': ['Jane Alexander',
#    'Lindsay Almond Jr.',
#    'Edward L. Ayers',
#    'Leon M. Bazile'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTU2NTgxOTU3Ml5BMl5BanBnXkFtZTcwNDU2OTgxNw@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Loving Story',
#   'fullplot': "A racially-charged criminal trial and a heart-rending love story converge in this documentary about Richard and Mildred Loving, set during the turbulent Civil Rights era. Long Way Home: The Loving Story is a story of love and the struggle for dignity set against a backdrop of historic anti-miscegenation sentiments in the U.S. The Lovings, an interracial couple, fell in love and married at a critical time in American history, and, because of a confluence of social and political turmoil our reluctant heroes bring about change where previously no one else could. They are paired with two young and ambitious lawyers who are driven to pave the way for Civil Rights and social justice through an historic Supreme Court ruling, changing the country's story forever.",
#   'languages': ['English'],
#   'released': datetime.datetime(2011, 4, 15, 0, 0),
#   'directors': ['Nancy Buirski'],
#   'writers': ['Nancy Buirski', 'Susie Ruth Powell'],
#   'awards': {'wins': 4, 'nominations': 2, 'text': '4 wins & 2 nominations.'},
#   'lastupdated': '2015-08-13 00:01:16.787000000',
#   'year': 2011,
#   'imdb': {'rating': 7.5, 'votes': 421, 'id': 1759682},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://lovingfilm.com/',
#    'viewer': {'rating': 4.2, 'numReviews': 929, 'meter': 86},
#    'dvd': datetime.datetime(2013, 5, 27, 0, 0),
#    'critic': {'rating': 8.5, 'numReviews': 16, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 9, 15, 17, 48, 21),
#    'rotten': 0,
#    'production': 'HBO Films',
#    'fresh': 16}},
#  {'_id': ObjectId('573a1398f29313caabcea5dc'),
#   'plot': "Three 'Bukowskian' torrid nights in the life of a man in search of love. Harry Voss, 12, is young and naive. Love, for him, is romantic love between princes and princesses demurely kissing ...",
#   'genres': ['Drama'],
#   'runtime': 90,
#   'title': 'Crazy Love',
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNTQyMjYwNzczNV5BMl5BanBnXkFtZTcwMzk0MjA0MQ@@._V1_SY1000_SX677_AL_.jpg',
#   'countries': ['Belgium'],
#   'fullplot': "Three 'Bukowskian' torrid nights in the life of a man in search of love. Harry Voss, 12, is young and naive. Love, for him, is romantic love between princes and princesses demurely kissing each other on the mouth. His father is a hero who kidnapped his mother and married her on a lonely mountain peak... Later on, he'll do the same. But Harry has a lot to learn. He also learns that there are handsome men and ugly ones, that love can be unfair. That one can find comfort in drinking... but above all he learns that man is capable of anything - absolutely anything! - to get his fair share of love.",
#   'languages': ['Dutch', 'Italian'],
#   'cast': ['Josse De Pauw', 'Geert Hunaerts', 'Michael Pas', 'Gene Bervoets'],
#   'directors': ['Dominique Deruddere'],
#   'writers': ['Charles Bukowski (novels)',
#    'Dominique Deruddere',
#    'Marc Didden'],
#   'awards': {'wins': 7, 'nominations': 0, 'text': '7 wins.'},
#   'lastupdated': '2015-08-25 00:07:43.540000000',
#   'year': 1987,
#   'imdb': {'rating': 7.0, 'votes': 860, 'id': 92794},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.6, 'numReviews': 1083, 'meter': 79},
#    'dvd': datetime.datetime(2004, 10, 26, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 8, 18, 18, 37, 13)}},
#  {'_id': ObjectId('573a1397f29313caabce7e21'),
#   'plot': "A high school student's love for a 15-year-old girl is thwarted by parental disapproval, circumstance and accident.",
#   'genres': ['Drama', 'Romance'],
#   'runtime': 116,
#   'rated': 'R',
#   'cast': ['Brooke Shields', 'Martin Hewitt', 'Shirley Knight', 'Don Murray'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BYWQ5MzNjNzgtNWY0Ni00ZGQxLWE5NmQtZmI2ZGMwNTQwM2RhXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Endless Love',
#   'fullplot': "Two young teenagers, Jade Butterfield and David Axelrod, fall in love with each other. But the passion is too consuming for Jade's bohemian parents. Her parents try to stop them from seeing each other. But when this doesn't work, David burns down the house and is sent to a mental hospital. This doesn't stop him from seeing her. When he gets out, he goes to look for her and remains in love with her. But in the end, the passion for his first love is too strong and she has to leave or this love will kill both of them.",
#   'languages': ['English'],
#   'released': datetime.datetime(1981, 7, 17, 0, 0),
#   'directors': ['Franco Zeffirelli'],
#   'writers': ['Scott Spencer (novel)', 'Judith Rascoe (screenplay)'],
#   'awards': {'wins': 3,
#    'nominations': 9,
#    'text': 'Nominated for 1 Oscar. Another 2 wins & 9 nominations.'},
#   'lastupdated': '2015-09-03 00:51:43.430000000',
#   'year': 1981,
#   'imdb': {'rating': 4.7, 'votes': 5136, 'id': 82329},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.2, 'numReviews': 7153, 'meter': 55},
#    'dvd': datetime.datetime(2014, 7, 6, 0, 0),
#    'critic': {'rating': 4.2, 'numReviews': 16, 'meter': 25},
#    'lastUpdated': datetime.datetime(2015, 8, 16, 18, 20, 49),
#    'rotten': 12,
#    'production': 'Universal',
#    'fresh': 4}},
#  {'_id': ObjectId('573a13a9f29313caabd1e69d'),
#   'fullplot': 'Against the backdrop of aged has-been rock star Billy Mack\'s Christmas themed comeback cover of "Love Is All Around" which he knows is crap and makes no bones about it much to his manager Joe\'s chagrin as he promotes the record, several interrelated stories about romantic love and the obstacles to happiness through love for Londoners are presented in the five weeks preceding Christmas. Daniel\'s wife has just passed away, leaving him to take care of his adolescent stepson Sam by himself. Daniel is uncertain how to deal with Sam and his problems without his wife present, especially in light of a potential budding romance within their household. Juliet and Peter have just gotten married. They believe that Peter\'s best friend and best man Mark hates Juliet but won\'t say so to his or her face. Others looking at the situation from the outside believe Mark is jealous of Juliet as he is in love with Peter himself. Jamie, a writer, is taking a writing retreat by himself in rural France following catching his latest girlfriend in an indiscretion. Jamie ends up spending much time in France with Aurèlia, the Portuguese woman hired as the housekeeper. The question becomes not only if they can communicate their day-to-day needs with each other as she speaks no English, he speaks no Portuguese, and neither speaks French well, but communicate what seems to be their increasing mutual attraction to each other. Sarah has been in love with her co-worker Karl for the two years they have worked together, this attraction which everyone in their workplace knows about. Sarah has to decide if she can be forward enough to express this love directly to Karl, especially in light of what has been her personal priority of dealing with a family issue. Harry and Karen have been in a stable long term marriage. His new assistant Mia drops hints to him that she would like them to be romantically involved. Harry has to decide whether to fall to the temptation, especially considering being married to a perceptive wife. Single and relatively young David is the newly elected Prime Minister. At 10 Downing Street, he is attracted to one of the new household servants, slightly overweight Natalie, but isn\'t sure what to do about it seeing as to their respective positions, the probable public scrutiny, and an incident involving the visiting U.S. President. Socially unaware Colin believes that the lack of romantic love in his life is all the fault of standoffish British women. As such, he decides to take decisive albeit somewhat unusual geographic action. And John and Judy are movie body doubles. They can communicate with each other straightforwardly while they are simulating sex filming a movie, but they may not be able to translate the feelings behind that simulation in real life to each other.',
#   'imdb': {'rating': 7.7, 'votes': 292304, 'id': 314331},
#   'year': 2003,
#   'plot': 'Follows the lives of eight very different couples in dealing with their love lives in various loosely interrelated tales all set during a frantic month before Christmas in London, England.',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'rated': 'R',
#   'metacritic': 55,
#   'title': 'Love Actually',
#   'lastupdated': '2015-09-05 00:57:24.743000000',
#   'languages': ['English', 'Portuguese', 'French'],
#   'writers': ['Richard Curtis'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.loveactually.com/',
#    'viewer': {'rating': 3.1, 'numReviews': 31624521, 'meter': 73},
#    'dvd': datetime.datetime(2004, 4, 27, 0, 0),
#    'critic': {'rating': 6.4, 'numReviews': 192, 'meter': 63},
#    'boxOffice': '$59.4M',
#    'consensus': 'A sugary tale overstuffed with too many stories. Still, the cast charms.',
#    'rotten': 72,
#    'production': 'Universal Pictures',
#    'lastUpdated': datetime.datetime(2015, 9, 11, 17, 3, 11),
#    'fresh': 120},
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTY4NjQ5NDc0Nl5BMl5BanBnXkFtZTYwNjk5NDM3._V1_SY1000_SX677_AL_.jpg',
#   'num_mflix_comments': 116,
#   'released': datetime.datetime(2003, 11, 14, 0, 0),
#   'awards': {'wins': 12,
#    'nominations': 24,
#    'text': 'Nominated for 2 Golden Globes. Another 10 wins & 24 nominations.'},
#   'countries': ['UK', 'USA', 'France'],
#   'cast': ['Bill Nighy', 'Gregor Fisher', 'Rory MacGregor', 'Colin Firth'],
#   'directors': ['Richard Curtis'],
#   'runtime': 135},
#  {'_id': ObjectId('573a13a0f29313caabd04510'),
#   'plot': "David, a recently fired scrapyard worker and Marie, a prostitute, both about 20 years old, meet on New Year's Eve in Berlin and decide to run away together. As David's arm is plastered from...",
#   'genres': ['Drama', 'Romance'],
#   'runtime': 137,
#   'cast': ['Sabine Timoteo',
#    'Florian Stetter',
#    'Michael Schech',
#    'Dierk Prawdzik'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTg0ODU5MTIxNF5BMl5BanBnXkFtZTcwNjk0NDQyMQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Love, Money, Love',
#   'fullplot': "David, a recently fired scrapyard worker and Marie, a prostitute, both about 20 years old, meet on New Year's Eve in Berlin and decide to run away together. As David's arm is plastered from an accident Marie continues to prostitute herself to finance their restless journey through the Ruhr area. Their love and their will to survive guide them though all problems.",
#   'languages': ['German'],
#   'released': datetime.datetime(2002, 11, 21, 0, 0),
#   'directors': ['Philip Grèning'],
#   'writers': ['Michael Busch', 'Philip Grèning'],
#   'awards': {'wins': 6, 'nominations': 5, 'text': '6 wins & 5 nominations.'},
#   'lastupdated': '2015-07-28 00:13:00.043000000',
#   'year': 2000,
#   'imdb': {'rating': 4.0, 'votes': 469, 'id': 203297},
#   'countries': ['Germany', 'Switzerland', 'France'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 2.9, 'numReviews': 2131, 'meter': 48},
#    'dvd': datetime.datetime(2000, 1, 11, 0, 0),
#    'production': 'Full Moon',
#    'lastUpdated': datetime.datetime(2015, 9, 11, 17, 56, 4)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a139bf29313caabcf25c4'),
#   'fullplot': "Detroit Tigers Veteran Pitcher Billy Chapel (Costner) has always been better at baseball than at love. Just ask Jane (Preston), his on-and-off girlfriend. After a bad season, just before he is about to start in what could be his final game, Jane tells Billy that she's leaving him...for good. Now with his career and love-life in balance, Billy battles against his emotional and physical limits as he strives for a Perfect Game. The suspense is never drawn back in this heartwarming drama about life, love, and risking it all For Love of the Game.",
#   'imdb': {'rating': 6.5, 'votes': 24676, 'id': 126916},
#   'year': 1999,
#   'plot': 'A washed up pitcher flashes through his career.',
#   'genres': ['Drama', 'Romance', 'Sport'],
#   'rated': 'PG-13',
#   'metacritic': 43,
#   'title': 'For Love of the Game',
#   'lastupdated': '2015-09-03 00:55:12.537000000',
#   'languages': ['English'],
#   'writers': ['Michael Shaara (novel)', 'Dana Stevens (screenplay)'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.universalpictures.com/forloveofthegame',
#    'viewer': {'rating': 3.3, 'numReviews': 43311, 'meter': 76},
#    'dvd': datetime.datetime(2000, 8, 15, 0, 0),
#    'critic': {'rating': 6.1, 'numReviews': 93, 'meter': 46},
#    'lastUpdated': datetime.datetime(2015, 9, 10, 17, 34, 35),
#    'consensus': 'Baseball wins, romance loses.',
#    'rotten': 50,
#    'production': 'Universal Pictures',
#    'fresh': 43},
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZDgzY2NkMTgtODQwZC00MWEzLWFlZjQtZTcxOTc3NzU1MDVhXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#   'num_mflix_comments': 1,
#   'released': datetime.datetime(1999, 9, 17, 0, 0),
#   'awards': {'wins': 0, 'nominations': 6, 'text': '6 nominations.'},
#   'countries': ['USA'],
#   'cast': ['Kevin Costner', 'Kelly Preston', 'John C. Reilly', 'Jena Malone'],
#   'directors': ['Sam Raimi'],
#   'runtime': 137},
#  {'_id': ObjectId('573a13b9f29313caabd4e21b'),
#   'fullplot': "Two feisty, free-spirited women are connected by the brilliant, charismatic poet who loves them both. The passion and pathos of legendary poet Dylan Thomas is told through the lives of two extraordinary women. Vera Phillips and Dylan were teenage loves; fast forward ten years and the two reconnect in London. She's working as a singer whilst he's churning out scripts for government propaganda films and living off the last in a long line of infatuated women. The two former lovers feel the thunderbolt once more, but Thomas is now married to the adventurous Caitlin. Despite their love-rival status, the women form a surprising friendship. Caitlin indulges in her own infidelities, and recognises a similar adventurous spirit in her husband. But she knows his connection with Vera is something different, not to mention dangerous. Romantic turmoil continues in Vera's life. She marries her devoted admirer William Killick, but she can't deny the chemistry between herself and Dylan, nor does she want to - even if this means betraying Caitlin. When William is posted abroad, and a pregnant Vera returns to Wales with her married friends, the battle between her heart and head becomes more intense. William returns a changed man, but neither is Vera the carefree cabaret girl he married. Neighbourhood gossip fuels her husband's jealousy towards his rival. Enraged, William stages a violent attack on Dylan - an attack that forces Vera to choose between the men in her life and the friend that she loves. Desire and guilt are complicated by love and friendship in this real-life tale set in beautiful London and the majestic Welsh countryside.",
#   'imdb': {'rating': 6.3, 'votes': 12630, 'id': 819714},
#   'year': 2008,
#   'plot': 'Two feisty, free-spirited women are connected by the brilliant, charismatic poet who loves them both.',
#   'genres': ['Biography', 'Drama', 'Romance'],
#   'rated': 'R',
#   'metacritic': 39,
#   'title': 'The Edge of Love',
#   'lastupdated': '2015-08-20 00:34:14.783000000',
#   'languages': ['English', 'Welsh'],
#   'writers': ['Sharman Macdonald'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.theedgeoflove.co.uk',
#    'viewer': {'rating': 3.0, 'numReviews': 53642, 'meter': 43},
#    'dvd': datetime.datetime(2009, 7, 14, 0, 0),
#    'critic': {'rating': 5.1, 'numReviews': 57, 'meter': 35},
#    'lastUpdated': datetime.datetime(2015, 8, 25, 19, 2, 34),
#    'consensus': 'Despite effective performances from Knightley and Miller, The Edge of Love lacks a coherent narrative.',
#    'rotten': 37,
#    'production': 'Capitol Films',
#    'fresh': 20},
#   'poster': 'https://m.media-amazon.com/images/M/MV5BOTI3NDNlMmEtMWQyOS00MmEzLTgxOTAtNGU2NzVjMzZiNzQ3XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#   'num_mflix_comments': 0,
#   'released': datetime.datetime(2008, 6, 20, 0, 0),
#   'awards': {'wins': 1, 'nominations': 2, 'text': '1 win & 2 nominations.'},
#   'countries': ['UK'],
#   'cast': ['Simon Armstrong', 'Ben Batt', 'Geoffrey Beevers', 'Rachel Bell'],
#   'directors': ['John Maybury'],
#   'runtime': 110},
#  {'_id': ObjectId('573a1397f29313caabce5c04'),
#   'plot': 'In czarist Russia, a neurotic soldier and his distant cousin formulate a plot to assassinate Napoleon.',
#   'genres': ['Comedy', 'War'],
#   'runtime': 85,
#   'rated': 'PG',
#   'cast': ['Woody Allen', 'Diane Keaton', 'Georges Adet', 'Frank Adu'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNGFkNDk4NmItZmQ4OS00YWIwLThiMTctZWYyMWQ3MjUxYjhlXkEyXkFqcGdeQXVyMjQzMzQzODY@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Love and Death',
#   'fullplot': "In Russia, Boris Grushenko is in love with his pseudo-intellectual cousin Sonja, who loves him since he too is a pseudo-intellectual, but she is not in love with him. Instead she is in love with his brother Ivan. But as Ivan doesn't seem to return her affections, she is determined to marry someone - anyone - except Boris. If that person isn't the perfect husband, then she has to find a suitable lover in addition. Boris' pursuit of Sonja has to take a back seat in his life when he, a pacifist and coward, is forced to join the Russian Army to battle Napoleon's forces which have just invaded Austria. Despite Sonja not being in the picture while he's away at war, Boris' thoughts do not stray totally from women. Although they take these two divergent paths in their lives, those paths cross once again as they, together, both try to find the perfect spouse and lover, and try to assassinate Napoleon.",
#   'languages': ['English'],
#   'released': datetime.datetime(1975, 9, 10, 0, 0),
#   'directors': ['Woody Allen'],
#   'writers': ['Woody Allen'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2015-09-05 00:56:38.510000000',
#   'year': 1975,
#   'imdb': {'rating': 7.8, 'votes': 25227, 'id': 73312},
#   'countries': ['France', 'USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 18652, 'meter': 90},
#    'dvd': datetime.datetime(2000, 7, 5, 0, 0),
#    'critic': {'rating': 8.1, 'numReviews': 19, 'meter': 100},
#    'lastUpdated': datetime.datetime(2015, 8, 24, 18, 46, 52),
#    'rotten': 0,
#    'production': 'United Artists',
#    'fresh': 19},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a13def29313caabdb6596'),
#   'plot': 'Documentary on the psychological aspects of growing up with and without parental love. It centers around the Diaz family, who chooses to adopt three orphans from Russia, and how their new and old kids handle family together.',
#   'genres': ['Documentary'],
#   'runtime': 93,
#   'title': 'The Dark Matter of Love',
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTg5OTY1MzgwNF5BMl5BanBnXkFtZTgwODIwOTcxMzE@._V1_SY1000_SX677_AL_.jpg',
#   'countries': ['UK'],
#   'fullplot': "ABOUT THE FILM Eleven year old Masha Kulabokhova is about to be adopted into fourteen year old Cami Diaz's family. Masha grew up in a Russian orphanage; Cami was born and raised in Wisconsin and has been the exclusive focus of her parents' love her whole life. The process of Masha becoming part of the Diaz family is going to change both girls forever. THE DARK MATTER OF LOVE follows Masha as she leaves Russia to spend her first year as part of the Diaz family, who have also adopted five year old twin boys Marcel and Vadim. When the reality of bonding with children who have grown up in institutions turns out to be more difficult than they ever imagined, the Diaz's hire two of the world's best developmental psychologists to help them build their new family - through science. Professor Emeritus at the University of Virginia School of Medicine, Dr Robert Marvin, has spent a lifetime developing a world-renowned therapy program that draws upon the past 100 years of scientific discoveries in the field of parent child love. By connecting the Diaz's with his research, Dr Marvin believes that he can help them create an environment in which Masha, Marcel and Vadim can form supportive, loving relationships. Sometimes hilarious, sometimes heartbreaking, THE DARK MATTER OF LOVE melds the story of the Diaz family learning to love, with rare archive footage of science experiments exploring parent child love. The science of love has an intriguing and dark past. Experiments on monkeys, birds and even human children have contributed to science's knowledge of love's inner workings. Director Sarah McCarthy fuses revealing footage of these experiments to the narrative, drawing audiences deeper into the dark matter of love and encouraging them to contemplate their own relationships through an unflinching, scientific lens.",
#   'languages': ['English'],
#   'released': datetime.datetime(2012, 11, 1, 0, 0),
#   'directors': ['Sarah McCarthy'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-30 00:48:25.367000000',
#   'year': 2012,
#   'imdb': {'rating': 7.4, 'votes': 537, 'id': 2512582},
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.9, 'numReviews': 88, 'meter': 79},
#    'dvd': datetime.datetime(2014, 12, 1, 0, 0),
#    'website': 'http://www.thedarkmatteroflove.com/',
#    'production': 'Virgil Films',
#    'lastUpdated': datetime.datetime(2015, 8, 22, 18, 25, 4)}},
#  {'_id': ObjectId('573a13b6f29313caabd463b7'),
#   'fullplot': "In Colombia just after the Great War, an old man falls from a ladder; dying, he professes great love for his wife. After the funeral, a man calls on the widow - she dismisses him angrily. Flash back more than 50 years to the day Florentino Ariza, a telegraph boy, falls in love with Fermina Daza, the daughter of a mule trader. Ariza is persistent, writing her constantly, serenading, speaking poetically of love. Her father tries to keep them apart, and then, one day, she sees this love as an illusion. She's soon married to Urbino, a cultured physician, and for years, Ariza carries a torch, finding solace in the arms of women, loving none. After Urbino's fall, are Ariza's hopes delusional?",
#   'imdb': {'rating': 6.4, 'votes': 18223, 'id': 484740},
#   'year': 2007,
#   'plot': 'Florentino, rejected by the beautiful Fermina at a young age, devotes much of his adult life to carnal affairs as a desperate attempt to heal his broken heart.',
#   'genres': ['Drama', 'Romance'],
#   'rated': 'R',
#   'metacritic': 43,
#   'title': 'Love in the Time of Cholera',
#   'lastupdated': '2015-09-11 00:33:17.500000000',
#   'languages': ['English'],
#   'writers': ['Ronald Harwood (screenplay)', 'Gabriel Garcèa Mèrquez (novel)'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.myspace.com/litc_film',
#    'viewer': {'rating': 3.1, 'numReviews': 32707, 'meter': 45},
#    'dvd': datetime.datetime(2008, 3, 18, 0, 0),
#    'critic': {'rating': 4.8, 'numReviews': 108, 'meter': 26},
#    'boxOffice': '$4.6M',
#    'consensus': "Though beautifully filmed, the makers of Love in the Time of Cholera fail to transfer the novel's magic to the screen.",
#    'rotten': 80,
#    'production': 'New Line Cinema',
#    'lastUpdated': datetime.datetime(2015, 8, 21, 18, 48, 22),
#    'fresh': 28},
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ3OTE0OTM4N15BMl5BanBnXkFtZTcwNDg3OTI1MQ@@._V1_SY1000_SX677_AL_.jpg',
#   'num_mflix_comments': 0,
#   'released': datetime.datetime(2007, 11, 16, 0, 0),
#   'awards': {'wins': 0,
#    'nominations': 3,
#    'text': 'Nominated for 1 Golden Globe. Another 2 nominations.'},
#   'countries': ['USA'],
#   'cast': ['Benjamin Bratt',
#    'Gina Bernard Forbes',
#    'Giovanna Mezzogiorno',
#    'Javier Bardem'],
#   'directors': ['Mike Newell'],
#   'runtime': 139},
#  {'_id': ObjectId('573a13b6f29313caabd46292'),
#   'plot': "Love. It just happens. No rules. It may look sick, but it's deep and it hurts. For everyone, Alex and Kiki are just good friends. They happen to be two girls experiencing another kind of love. For their family, Kiki and Sandu are sister and brother who sometimes fight. They happen to be lovers. Love Sick is about their stories.",
#   'genres': ['Drama'],
#   'runtime': 86,
#   'cast': ['Maria Popistasu',
#    'Ioana Barbu',
#    'Tudor Chirila',
#    'Catalina Murgea'],
#   'title': 'Love Sick',
#   'fullplot': "Love. It just happens. No rules. It may look sick, but it's deep and it hurts. For everyone, Alex and Kiki are just good friends. They happen to be two girls experiencing another kind of love. For their family, Kiki and Sandu are sister and brother who sometimes fight. They happen to be lovers. Love Sick is about their stories.",
#   'languages': ['Romanian'],
#   'released': datetime.datetime(2006, 6, 8, 0, 0),
#   'directors': ['Tudor Giurgiu'],
#   'writers': ['Razvan Radulescu (dialogue)',
#    'Cecilia Stefanescu (script & dialogue)'],
#   'awards': {'wins': 2, 'nominations': 9, 'text': '2 wins & 9 nominations.'},
#   'lastupdated': '2015-09-07 01:15:32.507000000',
#   'year': 2006,
#   'imdb': {'rating': 7.0, 'votes': 2352, 'id': 484437},
#   'countries': ['Romania', 'France'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.5, 'numReviews': 654, 'meter': 45},
#    'website': 'http://www.Lovesick-themovie.com/',
#    'production': 'Regent Releasing',
#    'lastUpdated': datetime.datetime(2015, 8, 22, 18, 29, 17)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1396f29313caabce40cb'),
#   'plot': 'A boy and a girl from different backgrounds fall in love regardless of their upbringing - and then tragedy strikes.',
#   'genres': ['Drama', 'Romance'],
#   'runtime': 99,
#   'metacritic': 84,
#   'rated': 'PG',
#   'cast': ['Ali MacGraw', "Ryan O'Neal", 'John Marley', 'Ray Milland'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BZmFjYWU1MGQtM2FiMi00YjA3LWIwYjUtZDdhYWEyOWFhZGE0XkEyXkFqcGdeQXVyMjI4MjA5MzA@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Love Story',
#   'fullplot': "Harvard Law student Oliver Barrett IV and music student Jennifer Cavilleri share a chemistry they cannot deny - and a love they cannot ignore. Despite their opposite backgrounds, the young couple put their hearts on the line for each other. When they marry, Oliver's wealthy father threatens to disown him. Jenny tries to reconcile the Barrett men, but to no avail. Oliver and Jenny continue to build their life together. Relying only on each other, they believe love can fix anything. But fate has other plans. Soon, what began as a brutally honest friendship becomes the love story of their lives.",
#   'languages': ['English'],
#   'released': datetime.datetime(1970, 12, 16, 0, 0),
#   'directors': ['Arthur Hiller'],
#   'writers': ['Erich Segal'],
#   'awards': {'wins': 13,
#    'nominations': 13,
#    'text': 'Won 1 Oscar. Another 12 wins & 13 nominations.'},
#   'lastupdated': '2015-08-31 00:37:45.793000000',
#   'year': 1970,
#   'imdb': {'rating': 6.9, 'votes': 21515, 'id': 66011},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.focusfilms.cc/film/lovestory.htm',
#    'viewer': {'rating': 3.5, 'numReviews': 35063, 'meter': 76},
#    'dvd': datetime.datetime(2001, 4, 24, 0, 0),
#    'critic': {'rating': 5.8, 'numReviews': 23, 'meter': 57},
#    'lastUpdated': datetime.datetime(2015, 8, 19, 18, 11, 12),
#    'rotten': 10,
#    'production': 'Paramount Pictures',
#    'fresh': 13},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1396f29313caabce42e5'),
#   'plot': "The battle of the sexes and relationships among the elite of Britian's industrial Midlands in the 1920s. Gerald Crich and Rupert Berkin are best friends who fall in love with a pair of ...",
#   'genres': ['Drama', 'Romance'],
#   'runtime': 131,
#   'rated': 'R',
#   'cast': ['Alan Bates', 'Oliver Reed', 'Glenda Jackson', 'Jennie Linden'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTY4NjA5MDQyOV5BMl5BanBnXkFtZTcwMTM5MTk3NA@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Women in Love',
#   'fullplot': "The battle of the sexes and relationships among the elite of Britian's industrial Midlands in the 1920s. Gerald Crich and Rupert Berkin are best friends who fall in love with a pair of sisters Gudrun, a sculptress and Ursula Brangwen, a schoolteacher. Rupert marries Ursula, Gerald begins a love affair with Gudrun, and the foursome embarks upon a Swiss honeymoon. But the relationships take markedly different directions, as Russell explores the nature of commitment and love. Rupert and Ursula learn to give themselves to each other; the more withdrawn Gerald cannot, finally, connect with the demanding and challenging Gudrun.",
#   'languages': ['English'],
#   'released': datetime.datetime(1970, 3, 25, 0, 0),
#   'directors': ['Ken Russell'],
#   'writers': ['D.H. Lawrence (novel)',
#    'Larry Kramer (written for the screen by)'],
#   'awards': {'wins': 7,
#    'nominations': 17,
#    'text': 'Won 1 Oscar. Another 6 wins & 17 nominations.'},
#   'lastupdated': '2015-09-05 00:50:21.073000000',
#   'year': 1969,
#   'imdb': {'rating': 7.6, 'votes': 4817, 'id': 66579},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.3, 'numReviews': 1393, 'meter': 44},
#    'dvd': datetime.datetime(2007, 1, 16, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 12, 17, 37, 28)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a1398f29313caabcea846'),
#   'plot': 'Mad love. Two physicians, one old and one young, fall in love with the same woman, Juliette, a quixotic hairdresser. First, she is with Raoul, the older one; then passion for Clèment, the ...',
#   'genres': ['Drama', 'Romance'],
#   'runtime': 122,
#   'cast': ['Nastassja Kinski',
#    'Jean-Hugues Anglade',
#    'Michel Piccoli',
#    'Jean-Claude Brialy'],
#   'title': 'Malady of Love',
#   'fullplot': "Mad love. Two physicians, one old and one young, fall in love with the same woman, Juliette, a quixotic hairdresser. First, she is with Raoul, the older one; then passion for Clèment, the younger doctor, takes over. Raoul fights back, playing on Clèment's guilt and Juliette's lack of self-assurance; then, Clèment makes his case to Juliette, abandons his fiancèe, and takes her to the provinces where he sets up practice and asks her to have a baby. She panics and abruptly leaves Clèment, taking up with Raoul again. When she contracts Hodgkin's disease and the treatment does no good, Raoul believes she has the malady of love. Is there a cure?",
#   'languages': ['French'],
#   'released': datetime.datetime(1987, 9, 30, 0, 0),
#   'directors': ['Jacques Deray'],
#   'writers': ['Danièle Thompson', 'Andrzej Zulawski (story)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-15 00:14:12.880000000',
#   'year': 1987,
#   'imdb': {'rating': 5.7, 'votes': 140, 'id': 93481},
#   'countries': ['France'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 2.9, 'numReviews': 467, 'meter': 36},
#    'production': 'MGM',
#    'lastUpdated': datetime.datetime(2015, 9, 3, 18, 38, 13)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a139bf29313caabcf51ba'),
#   'plot': 'A documentary on the life of Kurt Cobain and his relationship with Courtney Love.',
#   'genres': ['Documentary', 'Biography', 'Music'],
#   'runtime': 95,
#   'cast': ['Nick Broomfield', 'Kurt Cobain', 'Courtney Love', 'Al Bowman'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTM5NDc1MTE0M15BMl5BanBnXkFtZTcwMTkxNjYyMQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Kurt & Courtney',
#   'fullplot': "After rocker Kurt Cobain's death, ruled a suicide, a film crew arrives in Seattle to make a documentary. Director Nick Broomfield talks to lots of people: Cobain's aunt who provides home movies and recordings, the estranged father of Cobain's widow Courtney Love, an L.A. private investigator who worked for Love, a nanny for Kurt and Courtney's child, friends and lovers of both, and others. Although Love won't talk to him and his inquiries lose him financial backing, he comes to believe the coroner's verdict. Portraits emerge: a shy, slight Kurt, weary of touring, embarrassed by fame, hooked on heroin; an out-going Courtney, dramatic, controlling, moving from groupie to star.",
#   'languages': ['English'],
#   'released': datetime.datetime(1998, 2, 27, 0, 0),
#   'directors': ['Nick Broomfield'],
#   'rated': 'R',
#   'awards': {'wins': 1, 'nominations': 2, 'text': '1 win & 2 nominations.'},
#   'lastupdated': '2015-08-05 01:03:43.413000000',
#   'year': 1998,
#   'imdb': {'rating': 6.2, 'votes': 5031, 'id': 138563},
#   'countries': ['UK'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.1, 'numReviews': 6389, 'meter': 44},
#    'dvd': datetime.datetime(2001, 4, 10, 0, 0),
#    'critic': {'rating': 5.7, 'numReviews': 51, 'meter': 63},
#    'lastUpdated': datetime.datetime(2015, 8, 8, 18, 52, 46),
#    'rotten': 19,
#    'production': 'Roxie Releasing',
#    'fresh': 32},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a13bff29313caabd5f3fc'),
#   'plot': 'A drama centered around a married couple who opened the first legal brothel in Nevada.',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'runtime': 117,
#   'metacritic': 37,
#   'rated': 'R',
#   'cast': ['Helen Mirren',
#    'Joe Pesci',
#    'Sergio Peris-Mencheta',
#    'Gina Gershon'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQwNzgyNzA4OV5BMl5BanBnXkFtZTcwNzA0MDk0Mw@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Love Ranch',
#   'fullplot': "In the mid-70s, near Reno, Grace Bontempo runs the Love Ranch, a legal brothel. Her husband Charlie, with big dreams, a felony record, and an aptitude for spending and infidelity, is the brothel's public face. On the day Grace's doctor tells her she has cancer in an advanced state, Charlie takes on new client, Argentine boxer Armando Bruza, Charlie's ticket to fame: he hopes to promote a fight with Ali. Because of Charlie's felonies, Grace is Bruza's titular manager. With the IRS and the church ladies circling the business, Grace takes the manager's role seriously and, along the way, Bruza charms her. Secrets play out: is there love at the Love Ranch? How will Charlie respond?",
#   'languages': ['English'],
#   'released': datetime.datetime(2011, 1, 6, 0, 0),
#   'directors': ['Taylor Hackford'],
#   'writers': ['Mark Jacobson'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2015-08-20 00:16:57.610000000',
#   'year': 2010,
#   'imdb': {'rating': 5.6, 'votes': 2252, 'id': 1125929},
#   'countries': ['USA', 'Germany'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 2.6, 'numReviews': 1211, 'meter': 28},
#    'dvd': datetime.datetime(2010, 11, 9, 0, 0),
#    'critic': {'rating': 3.7, 'numReviews': 51, 'meter': 12},
#    'boxOffice': '$0.1M',
#    'consensus': 'Despite its saucy setup and the always marvelous Helen Mirren, Love Ranch is disappointingly flaccid.',
#    'rotten': 45,
#    'production': 'E1 Entertainment',
#    'lastUpdated': datetime.datetime(2015, 9, 17, 17, 38, 13),
#    'fresh': 6},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a13a5f29313caabd1568e'),
#   'plot': 'Fifteen year ago, Carlos went to the cinema to meet Jèlia, his university colleague with whom he was in love. She never showed up. Carlos was left waiting in the lobby alone. While he waits...',
#   'genres': ['Comedy', 'Romance', 'Drama'],
#   'runtime': 98,
#   'cast': ['Murilo Benècio',
#    'Carolina Ferraz',
#    'Emèlio de Mello',
#    'Beth Goulart'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BODY5NTA0NTA1MF5BMl5BanBnXkFtZTcwMjE3OTYyMQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Possible Loves',
#   'fullplot': "Fifteen year ago, Carlos went to the cinema to meet Jèlia, his university colleague with whom he was in love. She never showed up. Carlos was left waiting in the lobby alone. While he waits, something happens which will change his life. A scene, an encounter, an unfinished sentence... Something insignificant, but which will determine the character's life. Fifteen years later, we follow three completely different versions of Carlos's life. In one, he is a man divided between the stability of a secure life in a lukewarm marriage, and the growing desire to live a great love affair. In the second, he is homosexual and places passion above all else. In the third possible life, Carlos is a man who hasn't yet discovered love, and lives through successive disastrous relationships in search of the perfect woman. One of them is his real life. Another is not his life. And a third is the life he'd like to lead. Which is his true life ?",
#   'languages': ['Portuguese'],
#   'released': datetime.datetime(2001, 3, 30, 0, 0),
#   'directors': ['Sandra Werneck'],
#   'writers': ['Maya Da-Rin (story)', 'Paulo Halm'],
#   'awards': {'wins': 2, 'nominations': 4, 'text': '2 wins & 4 nominations.'},
#   'lastupdated': '2015-09-02 00:16:46.147000000',
#   'year': 2001,
#   'imdb': {'rating': 6.9, 'votes': 919, 'id': 275915},
#   'countries': ['Brazil'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.1, 'numReviews': 946, 'meter': 57},
#    'dvd': datetime.datetime(2003, 7, 15, 0, 0),
#    'production': 'TLA Releasing',
#    'lastUpdated': datetime.datetime(2015, 7, 26, 18, 23, 49)}},
#  {'_id': ObjectId('573a139bf29313caabcf500b'),
#   'fullplot': "Will Shakespeare is a known but struggling poet, playwright and actor who not only has sold his next play to both Philip Henslow and Richard Burbidge but now faces a far more difficult problem: he is bereft of ideas and has yet to begin writing. He is in search of his muse, the woman who will inspire him but all attempts fail him until he meets the beautiful Viola de Lesseps. She loves the theatre and would like nothing more than to take to the stage but is forbidden from doing so as only men can be actors. She is also a great admirer of Shakespeare's works. Dressing as a man and going by the name of Thomas Kent, she auditions and is ideal for a part in his next play. Shakespeare soon sees through her disguise and they begin a love affair, one they know cannot end happily for them as he is already married and she has been promised to the dour Lord Wessex. As the company rehearses his new play, Will and Viola's love is transferred to the written page leading to the masterpiece that is Romeo and Juliet.",
#   'imdb': {'rating': 7.2, 'votes': 164218, 'id': 138097},
#   'year': 1998,
#   'plot': 'A young Shakespeare, out of ideas and short of cash, meets his ideal woman and is inspired to write one of his most famous plays.',
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'rated': 'R',
#   'metacritic': 87,
#   'title': 'Shakespeare in Love',
#   'lastupdated': '2015-09-10 17:25:08.083000000',
#   'languages': ['English'],
#   'writers': ['Marc Norman', 'Tom Stoppard'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.miramax.com/mm_front/owa/mp.entryPoint?action=0&midStr=742',
#    'viewer': {'rating': 3.4, 'numReviews': 225703, 'meter': 80},
#    'dvd': datetime.datetime(1999, 8, 10, 0, 0),
#    'critic': {'rating': 8.3, 'numReviews': 125, 'meter': 92},
#    'lastUpdated': datetime.datetime(2015, 9, 14, 21, 38, 20),
#    'consensus': 'Endlessly witty, visually rapturous, and sweetly romantic, Shakespeare in Love is a delightful romantic comedy that succeeds on nearly every level.',
#    'rotten': 10,
#    'production': 'Miramax',
#    'fresh': 115},
#   'poster': 'https://m.media-amazon.com/images/M/MV5BM2ZkNjM5MjEtNTBlMC00OTI5LTgyYmEtZDljMzNmNzhiNzY0XkEyXkFqcGdeQXVyNDYyMDk5MTU@._V1_SY1000_SX677_AL_.jpg',
#   'num_mflix_comments': 1,
#   'released': datetime.datetime(1999, 1, 8, 0, 0),
#   'awards': {'wins': 70,
#    'nominations': 77,
#    'text': 'Won 7 Oscars. Another 63 wins & 77 nominations.'},
#   'countries': ['USA'],
#   'cast': ['Geoffrey Rush',
#    'Tom Wilkinson',
#    "Steven O'Donnell",
#    'Tim McMullan'],
#   'directors': ['John Madden'],
#   'runtime': 123},
#  {'_id': ObjectId('573a13c1f29313caabd65e09'),
#   'plot': 'An examination of the social costs of corporate interests pursuing profits at the expense of the public good.',
#   'genres': ['Documentary'],
#   'runtime': 127,
#   'metacritic': 61,
#   'rated': 'R',
#   'cast': ['Thora Birch', 'William Black', 'Jimmy Carter', 'Elijah Cummings'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTYyMTA2MTE4NF5BMl5BanBnXkFtZTcwNTgwMDE4Mg@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Capitalism: A Love Story',
#   'fullplot': 'Capitalism: A Love Story examines the impact of corporate dominance on the everyday lives of Americans (and by default, the rest of the world). The film moves from Middle America, to the halls of power in Washington, to the global financial epicenter in Manhattan. With both humor and outrage, the film explores the question: What is the price that America pays for its love of capitalism? Families pay the price with their jobs, their homes and their savings. Moore goes into the homes of ordinary people whose lives have been turned upside down; and he goes looking for explanations in Washington, DC and elsewhere. What he finds are the all-too-familiar symptoms of a love affair gone astray: lies, abuse, betrayal...and 14,000 jobs being lost every day. Capitalism: A Love Story also presents what a more hopeful future could look like. Who are we and why do we behave the way that we do?',
#   'languages': ['English', 'Russian', 'Spanish'],
#   'released': datetime.datetime(2009, 10, 2, 0, 0),
#   'directors': ['Michael Moore'],
#   'writers': ['Michael Moore'],
#   'awards': {'wins': 7, 'nominations': 9, 'text': '7 wins & 9 nominations.'},
#   'lastupdated': '2015-09-07 00:44:47.640000000',
#   'year': 2009,
#   'imdb': {'rating': 7.4, 'votes': 32630, 'id': 1232207},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.capitalismalovestory.com/',
#    'viewer': {'rating': 3.6, 'numReviews': 70389, 'meter': 73},
#    'dvd': datetime.datetime(2010, 3, 9, 0, 0),
#    'critic': {'rating': 6.7, 'numReviews': 178, 'meter': 75},
#    'boxOffice': '$14.3M',
#    'consensus': 'Love him or hate him, Capitalism captures Michael Moore in his muckraking element -- with all the Moore-centric showmanship that entails.',
#    'rotten': 45,
#    'production': 'Overture Films',
#    'lastUpdated': datetime.datetime(2015, 8, 21, 18, 31, 22),
#    'fresh': 133},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a13f1f29313caabddb616'),
#   'plot': "A sexual melodrama about a boy and a girl and another girl. It's a love story, which celebrates sex in a joyous way.",
#   'genres': ['Drama', 'Romance'],
#   'runtime': 134,
#   'metacritic': 54,
#   'cast': ['Aomi Muyock', 'Karl Glusman', 'Klara Kristin', 'Juan Saavedra'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNDUwODk5NF5BMl5BanBnXkFtZTgwNzA0MDQ2NTE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Love',
#   'fullplot': "A sexual melodrama about a boy and a girl and another girl. It's a love story, which celebrates sex in a joyous way.",
#   'languages': ['English'],
#   'released': datetime.datetime(2015, 11, 6, 0, 0),
#   'directors': ['Gaspar Noè'],
#   'writers': ['Gaspar Noè'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-09-05 00:41:35.807000000',
#   'year': 2015,
#   'imdb': {'rating': 6.3, 'votes': 660, 'id': 3774694},
#   'countries': ['France', 'Belgium'],
#   'type': 'movie'},
#  {'_id': ObjectId('573a13b6f29313caabd477fa'),
#   'plot': 'With the help of his uncle, a man travels to the future to try and bring his girlfriend back to life.',
#   'genres': ['Action', 'Adventure', 'Drama'],
#   'runtime': 180,
#   'cast': ['Harman Baweja',
#    'Priyanka Chopra',
#    'Boman Irani',
#    'Archana Puran Singh'],
#   'num_mflix_comments': 0,
#   'title': 'Love Story 2050',
# ...
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-12 00:52:54.487000000',
#   'year': 2011,
#   'imdb': {'rating': 6.8, 'votes': 436, 'id': 1672621},
#   'countries': ['Ireland', 'USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 0.5, 'numReviews': 1},
#    'production': 'Global Universal Pictures',
#    'lastUpdated': datetime.datetime(2014, 11, 25, 14, 14, 25)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a13ccf29313caabd835e8'),
#   'plot': "An uptight NYC lawyer takes her two teenagers to her hippie mother's farmhouse upstate for a family vacation.",
#   'genres': ['Comedy', 'Drama', 'Music'],
#   'runtime': 96,
#   'metacritic': 45,
#   'rated': 'R',
#   'cast': ['Jane Fonda', 'Catherine Keener', 'Ann Osmond', 'Rbert Bowen Jr.'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTY1ODAxMzYyNF5BMl5BanBnXkFtZTcwMjQ1MDM3Nw@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Peace, Love, & Misunderstanding',
#   'fullplot': "An uptight NYC lawyer takes her two teenagers to her hippie mother's farmhouse upstate for a family vacation. What was meant to be a weekend getaway quickly turns into a summer adventure of romance, music, family secrets and self-discovery.",
#   'languages': ['English'],
#   'released': datetime.datetime(2012, 8, 16, 0, 0),
#   'directors': ['Bruce Beresford'],
#   'writers': ['Christina Mengert', 'Joseph Muszynski'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-09-17 04:42:20.240000000',
#   'year': 2011,
#   'imdb': {'rating': 5.9, 'votes': 5459, 'id': 1649780},
#   'countries': ['USA'],
#   'type': 'movie',
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a13ccf29313caabd83278'),
#   'plot': 'Anna a young teenager comes home from her Catholic boarding school for the holidays and discovers her father has left. Her mother is devastated and confined in the company of the local ...',
#   'genres': ['Drama'],
#   'runtime': 92,
#   'cast': ['Clara Augarde', 'Lio', 'Michel Galabru', 'Stefano Cassetti'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNGM3ZmQ2ZWUtOTdkZC00YzAzLWJhMmEtNWJhMzZhMmMxNzZhXkEyXkFqcGdeQXVyMTMxMTY0OTQ@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Love Like Poison',
#   'fullplot': "Anna a young teenager comes home from her Catholic boarding school for the holidays and discovers her father has left. Her mother is devastated and confined in the company of the local priest, who is also a childhood friend. Anna clings to her beloved grandfather. She also grows close to Pierre, a free-spirited teenager who cares little about God. Anna is preparing for her confirmation, but her budding desire for Pierre shakes her faith. She longs to give herself over, body and soul... but doesn't know if it is to God, or something else?",
#   'languages': ['French', 'Italian', 'English'],
#   'released': datetime.datetime(2010, 8, 4, 0, 0),
#   'directors': ['Katell Quillèvèrè'],
#   'writers': ['Mariette Dèsert (collaboration)', 'Katell Quillèvèrè'],
#   'awards': {'wins': 1, 'nominations': 2, 'text': '1 win & 2 nominations.'},
#   'lastupdated': '2015-08-09 00:04:39.320000000',
#   'year': 2010,
#   'imdb': {'rating': 6.5, 'votes': 520, 'id': 1646985},
#   'countries': ['France'],
#   'type': 'movie'},
#  {'_id': ObjectId('573a13ccf29313caabd81c94'),
#   'plot': 'A young woman takes a job at a massage parlor to support her family when her husband is unable to work, and soon finds her life spiraling out of control.',
#   'genres': ['Drama'],
#   'runtime': 88,
#   'rated': 'TV-14',
#   'cast': ['Jennifer Love Hewitt',
#    'Teddy Sears',
#    'Sonja Bennett',
#    'Lynda Boyd'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTM1MjQ0Nzc5OF5BMl5BanBnXkFtZTcwODQ1NzcxNA@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Client List',
#   'fullplot': 'A former beauty queen is forced to take a job at a massage parlor when her family faces foreclosure on their home after her husband suffers an injury that keeps him from working. Unfortunately for her she soon learns that her clients expect more than a rubdown.',
#   'languages': ['English'],
#   'released': datetime.datetime(2010, 7, 19, 0, 0),
#   'directors': ['Eric Laneuville'],
#   'writers': ['Suzanne Martin'],
#   'awards': {'wins': 2,
#    'nominations': 0,
#    'text': 'Nominated for 1 Golden Globe. Another 1 win.'},
#   'lastupdated': '2015-09-12 00:24:31.280000000',
#   'year': 2010,
#   'imdb': {'rating': 5.8, 'votes': 4442, 'id': 1625340},
#   'countries': ['USA'],
#   'type': 'movie'},
#  {'_id': ObjectId('573a13caf29313caabd7d9b2'),
#   'fullplot': 'Cal (Steve Carell) and Emily (Julianne Moore) have the perfect life together living the American dream... until Emily asks for a divorce. Now Cal, Mr Husband, has to navigate the single scene with a little help from his professional bachelor friend Jacob Palmer (Ryan Gosling). Make that a lot of help...',
#   'imdb': {'rating': 7.4, 'votes': 347819, 'id': 1570728},
#   'year': 2011,
#   'plot': "A middle-aged husband's life changes dramatically when his wife asks him for a divorce. He seeks to rediscover his manhood with the help of a newfound friend, Jacob, learning to pick up girls at bars.",
#   'genres': ['Comedy', 'Drama', 'Romance'],
#   'rated': 'PG-13',
#   'metacritic': 68,
#   'title': 'Crazy, Stupid, Love.',
#   'lastupdated': '2015-08-31 00:01:28.687000000',
#   'languages': ['English'],
#   'writers': ['Dan Fogelman'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.crazystupidlovemovie.com',
#    'viewer': {'rating': 3.8, 'numReviews': 106124, 'meter': 77},
#    'dvd': datetime.datetime(2011, 11, 1, 0, 0),
#    'critic': {'rating': 6.9, 'numReviews': 203, 'meter': 78},
#    'boxOffice': '$84.3M',
#    'consensus': "It never lives up to the first part of its title, but Crazy, Stupid, Love's unabashed sweetness -- and its terrifically talented cast -- more than make up for its flaws.",
#    'rotten': 45,
#    'production': 'Warner Bros. Pictures',
#    'lastUpdated': datetime.datetime(2015, 9, 12, 17, 6, 25),
#    'fresh': 158},
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTg2MjkwMTM0NF5BMl5BanBnXkFtZTcwMzc4NDg2NQ@@._V1_SY1000_SX677_AL_.jpg',
#   'num_mflix_comments': 0,
#   'released': datetime.datetime(2011, 7, 29, 0, 0),
#   'awards': {'wins': 5,
#    'nominations': 19,
#    'text': 'Nominated for 1 Golden Globe. Another 4 wins & 19 nominations.'},
#   'countries': ['USA'],
#   'cast': ['Steve Carell', 'Ryan Gosling', 'Julianne Moore', 'Emma Stone'],
#   'directors': ['Glenn Ficarra', 'John Requa'],
#   'runtime': 118},
#  {'_id': ObjectId('573a13c8f29313caabd78c2c'),
#   'plot': 'Onur, who has been deaf since birth, works as a librarian. His father had left him and his mother when he was seven, and Onur has always blamed himself for this. Although being able to ...',
#   'genres': ['Drama'],
#   'runtime': 98,
#   'cast': ['Mert Firat', 'Saadet Aksoy', 'Emre Karayel', 'Lale Mansur'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjAyODk4Nzc2M15BMl5BanBnXkFtZTcwODg0MDQwOQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Love in Another Language',
#   'fullplot': "Onur, who has been deaf since birth, works as a librarian. His father had left him and his mother when he was seven, and Onur has always blamed himself for this. Although being able to speak, he has chosen to stay silent because of the pitying looks of the people around him. At his friend Vedat's engagement party, he meets Zeynep, who later finds out about Onur's hearing disability, but is not bothered by it. She is forced by her overbearing father to leave home and gets a job at a call-center. Having to speak on the phone all day to people she doesn't know, Zeynep finds peace with Onur, who she communicates with perfectly without speaking...",
#   'languages': ['Turkish', 'Sign Languages'],
#   'released': datetime.datetime(2009, 12, 18, 0, 0),
#   'directors': ['Ilksen Basarir'],
#   'writers': ['Ilksen Basarir', 'Mert Firat'],
#   'awards': {'wins': 6, 'nominations': 1, 'text': '6 wins & 1 nomination.'},
#   'lastupdated': '2015-08-30 00:42:29.117000000',
#   'year': 2009,
#   'imdb': {'rating': 7.5, 'votes': 4832, 'id': 1513713},
#   'countries': ['Turkey'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 153},
#    'lastUpdated': datetime.datetime(2015, 9, 11, 17, 44, 59)}},
#  {'_id': ObjectId('573a13c5f29313caabd70e7c'),
#   'plot': 'As a child Takuma is diagnosed with a heart condition that requires care from a cardiologist. He soon becomes friends with his doctors young daughter Mayu while being treated at the ...',
#   'genres': ['Drama', 'Romance'],
#   'runtime': 122,
#   'cast': ['Mao Inoue', 'Masaki Okada', 'Natsuki Harada', 'Keiko Horiuchi'],
#   'num_mflix_comments': 1,
#   'title': 'I Give My First Love to You',
#   'fullplot': "As a child Takuma is diagnosed with a heart condition that requires care from a cardiologist. He soon becomes friends with his doctors young daughter Mayu while being treated at the hospital. One day Mayu overhears her father saying that Takumas condition is serious enough that he most likely wont live beyond the age of 20. Takuma isn't aware of this himself, however, so at 8-years-old he makes a promise to marry Mayu when they turn 20. Later in life, Takuma becomes aware that he wont be able to keep this promise and he begins distancing himself from Mayu in hopes of protecting her.",
#   'languages': ['Japanese'],
#   'released': datetime.datetime(2009, 10, 24, 0, 0),
#   'directors': ['Takehiko Shinjo'],
#   'writers': ['Kotomi Aoki (manga)', 'Kenji Bando (screenplay)'],
#   'awards': {'wins': 4, 'nominations': 0, 'text': '4 wins.'},
#   'lastupdated': '2015-09-01 00:52:38.583000000',
#   'year': 2009,
#   'imdb': {'rating': 7.4, 'votes': 1088, 'id': 1401656},
#   'countries': ['Japan'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 4.0, 'numReviews': 18},
#    'lastUpdated': datetime.datetime(2015, 7, 2, 19, 22, 36)}},
#  {'_id': ObjectId('573a13bff29313caabd60945'),
#   'plot': "Water is the very essence of life, sustaining every being on the planet. 'Flow' confronts the disturbing reality that our crucial resource is dwindling and greed just may be the cause.",
#   'genres': ['Documentary'],
#   'runtime': 93,
#   'metacritic': 67,
#   'cast': ['Bill Alexander', 'Maude Barlow', 'Basil Bold', 'Shelly Brime'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQwMzU0OTA5OF5BMl5BanBnXkFtZTcwNDgwMTk3MQ@@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Flow: For Love of Water',
#   'fullplot': "Water is the very essence of life, sustaining every being on the planet. 'Flow' confronts the disturbing reality that our crucial resource is dwindling and greed just may be the cause.",
#   'languages': ['English'],
#   'released': datetime.datetime(2011, 12, 15, 0, 0),
#   'directors': ['Irena Salina'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2015-08-19 00:19:39.360000000',
#   'year': 2008,
#   'imdb': {'rating': 7.6, 'votes': 1008, 'id': 1149583},
#   'countries': ['USA'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 1.3, 'numReviews': 46},
#    'dvd': datetime.datetime(2008, 4, 8, 0, 0),
#    'website': 'http://www.flowthefilm.com/',
#    'production': 'Oscilloscope Pictures',
#    'lastUpdated': datetime.datetime(2015, 9, 15, 17, 5, 7)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a13bff29313caabd5fca1'),
#   'plot': 'A drama based on the memoir of Amos Oz, a writer, journalist, and advocate of a two-state solution to the Israeli-Palestinian conflict.',
#   'genres': ['Drama'],
#   'runtime': 95,
#   'metacritic': 51,
#   'cast': ['Natalie Portman', 'Makram Khoury', 'Shira Haas', 'Gilad Kahana'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjIyNzk2MTY0Ml5BMl5BanBnXkFtZTgwMzExNTA2OTE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'A Tale of Love and Darkness',
#   'fullplot': 'A drama based on the memoir of Amos Oz, a writer, journalist, and advocate of a two-state solution to the Israeli-Palestinian conflict.',
#   'languages': ['Hebrew'],
#   'released': datetime.datetime(2015, 5, 16, 0, 0),
#   'directors': ['Natalie Portman'],
#   'writers': ['Amos Oz (memoir)', 'Natalie Portman (screenplay)'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-08-20 00:05:14.187000000',
#   'year': 2015,
#   'imdb': {'rating': 5.5, 'votes': 121, 'id': 1135989},
#   'countries': ['Israel'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 0.0, 'numReviews': 25},
#    'lastUpdated': datetime.datetime(2015, 8, 22, 19, 5, 31)},
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a13bff29313caabd5ec26'),
#   'plot': 'A teenage boy loses his footing when he finds himself drawn to the new boy in class.',
#   'genres': ['Comedy', 'Drama', 'Music'],
#   'runtime': 90,
#   'cast': ['Rolf Kristian Larsen',
#    'Arthur Berning',
#    'Ida Elise Broch',
#    'Ole Christoffer Ertvaag'],
#   'num_mflix_comments': 0,
#   'title': 'The Man Who Loved Yngve',
#   'fullplot': "It's November 1989, and the Berlin Wall is falling. In Stavanger, Norway, teenage boy Jarle has a great new girlfriend and is starting a rock band with his buddies. But when a new boy, the synth pop-listening Yngve, joins his class, Jarle is more fascinated than he wants to be, and the world as he knows it starts to crumble.",
#   'languages': ['Norwegian'],
#   'released': datetime.datetime(2008, 2, 15, 0, 0),
#   'directors': ['Stian Kristiansen'],
#   'writers': ['Tore Renberg (novel)', 'Tore Renberg (screenplay)'],
#   'awards': {'wins': 5, 'nominations': 5, 'text': '5 wins & 5 nominations.'},
#   'lastupdated': '2015-08-30 00:12:56.197000000',
#   'year': 2008,
#   'imdb': {'rating': 7.1, 'votes': 3168, 'id': 1114723},
#   'countries': ['Norway'],
#   'type': 'movie',
#   'tomatoes': {'viewer': {'rating': 3.8, 'numReviews': 1814, 'meter': 79},
#    'lastUpdated': datetime.datetime(2015, 8, 26, 18, 0, 39)}},
#  {'_id': ObjectId('573a13bef29313caabd5aebe'),
#   'fullplot': "Steven Russell is happily married to Debbie, and a member of the local police force when a car accident provokes a dramatic reassessment of his life. Steven becomes open about his homosexuality and decides to live life to the fullest - even if it means breaking the law. Steven's new, extravagant lifestyle involves cons and fraud and, eventually, a stay in the State Penitentiary where he meets sensitive, soft-spoken Phillip Morris. His devotion to freeing Phillip from jail and building the perfect life together prompts Steven to attempt and often succeed at one impossible con after another.",
#   'imdb': {'rating': 6.7, 'votes': 72329, 'id': 1045772},
#   'year': 2009,
#   'plot': "A cop turns con man once he comes out of the closet. Once imprisoned, he meets the second love of his life, whom he'll stop at nothing to be with.",
#   'genres': ['Biography', 'Comedy', 'Crime'],
#   'rated': 'R',
#   'metacritic': 65,
#   'title': 'I Love You Phillip Morris',
#   'lastupdated': '2015-09-10 17:08:33.303000000',
#   'languages': ['English'],
#   'writers': ['John Requa', 'Glenn Ficarra', 'Steve McVicker (book)'],
#   'type': 'movie',
#   'tomatoes': {'website': 'http://www.phillipmorristhemovie.com/',
#    'viewer': {'rating': 3.3, 'numReviews': 88118, 'meter': 61},
#    'dvd': datetime.datetime(2011, 4, 5, 0, 0),
#    'critic': {'rating': 6.6, 'numReviews': 152, 'meter': 72},
#    'boxOffice': '$2.0M',
#    'consensus': "This fact-based romantic comedy has its flaws, but they're mostly overcome by its consistently sweet, funny tone and one of the best performances of Jim Carrey's career.",
#    'rotten': 43,
#    'production': 'Roadside Attractions',
#    'lastUpdated': datetime.datetime(2015, 9, 13, 18, 18, 44),
#    'fresh': 109},
#   'poster': 'https://m.media-amazon.com/images/M/MV5BNDkzMjkwNjc5NV5BMl5BanBnXkFtZTcwNzEyOTk5Mw@@._V1_SY1000_SX677_AL_.jpg',
#   'num_mflix_comments': 0,
#   'released': datetime.datetime(2011, 1, 7, 0, 0),
#   'awards': {'wins': 5, 'nominations': 8, 'text': '5 wins & 8 nominations.'},
#   'countries': ['France', 'USA'],
#   'cast': ['Jim Carrey', 'Ewan McGregor', 'Leslie Mann', 'Rodrigo Santoro'],
#   'directors': ['Glenn Ficarra', 'John Requa'],
#   'runtime': 98},
#  ...]

# %%
# Text search across title and plot, sorted by IMDb rating
war_movies = collection.find({"$text": {"$search": "war"}}).sort("imdb.rating", -
1).limit(5)
list(war_movies)
# Out:
# [{'_id': ObjectId('573a13f2f29313caabddcf5f'),
#   'plot': "Company commander Claus M. Pedersen (Pilou Asbèk) and his men are stationed in an Afghan province. Meanwhile back in Denmark Claus' wife Maria (Tuva Novotny) is trying to hold everyday life...",
#   'genres': ['Drama', 'War'],
#   'countries': ['Denmark'],
#   'cast': ['Pilou Asbèk', 'Tuva Novotny', 'Sèren Malling', 'Dar Salim'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMjA1ODY3NjQzNV5BMl5BanBnXkFtZTgwNjEzNTUxNzE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'A War',
#   'fullplot': "Company commander Claus M. Pedersen (Pilou Asbèk) and his men are stationed in an Afghan province. Meanwhile back in Denmark Claus' wife Maria (Tuva Novotny) is trying to hold everyday life together with a husband at war and three children missing their father. During a routine mission, the soldiers are caught in heavy crossfire and in order to save his men, Claus makes a decision that has grave consequences for him - and his family back home.",
#   'languages': ['Danish'],
#   'released': datetime.datetime(2015, 9, 10, 0, 0),
#   'directors': ['Tobias Lindholm'],
#   'writers': ['Tobias Lindholm'],
#   'awards': {'wins': 0, 'nominations': 1, 'text': '1 nomination.'},
#   'lastupdated': '2015-09-05 00:28:23.783000000',
#   'year': 2015,
#   'imdb': {'rating': '', 'votes': '', 'id': 3830162},
#   'type': 'movie'},
#  {'_id': ObjectId('573a13f5f29313caabde2db9'),
#   'plot': 'On her first day in Afghanistan, an interpreter for the US Army is forced to deliver the child of an enemy bomb-maker.',
#   'genres': ['Short', 'Drama', 'War'],
#   'runtime': 25,
#   'cast': ['Layla Alizada', 'Navid Negahban', 'Alexia Pearl', 'Bill Zasadil'],
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTQxNzMyNzI1OV5BMl5BanBnXkFtZTgwMjc4MDYwMzE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Day One',
#   'fullplot': "Inspired by a true story, an Afghan-American woman on the heels of a divorce joins the US Military as an interpreter. On her first day of deployment in Afghanistan, her unit searches out the remote house of a bomb-maker. When the bomb-maker's pregnant wife goes into labor, the interpreter must go beyond the call of duty to deliver her breech child.",
#   'languages': ['English', 'Dari'],
#   'released': datetime.datetime(2015, 4, 16, 0, 0),
#   'directors': ['Henry Hughes'],
#   'writers': ['Dawn DeVoe (story)',
#    'Henry Hughes (story)',
#    'Henry Hughes',
#    'Henry Hughes'],
#   'awards': {'wins': 2, 'nominations': 0, 'text': '2 wins.'},
#   'lastupdated': '2015-06-17 18:42:27.423000000',
#   'year': 2015,
#   'imdb': {'rating': '', 'votes': '', 'id': 4122886},
#   'countries': ['USA'],
#   'type': 'movie',
#   'num_mflix_comments': 0},
#  {'_id': ObjectId('573a13ecf29313caabdd1fc2'),
#   'plot': 'American Hostage pulls back the curtains on a terrorist plot centered on a group of terrorists holding two American soldiers hostage on U.S. soil. They demand the release of all prisoners of Guantanamo Bay or they will kill the soldiers.',
#   'genres': ['Crime', 'Drama', 'Thriller'],
#   'runtime': 100,
#   'cast': ['Charles Martin Garcia',
#    'Davina Reid',
#    'Leon Salem',
#    'Marion Blount'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTA4NTcyMzQ0NTBeQTJeQWpwZ15BbWU4MDYwMTAwMDUx._V1_SY1000_SX677_AL_.jpg',
#   'title': 'American Hostage',
#   'fullplot': "Terrorists. Kidnapping. A plot gone wrong. American Hostage tells the story of four terrorists coming together to create change within the American government and affect their stance on Guantanamo Bay. With tensions high, emotions between the terrorists collide, which sets the story into a downward spiral. American Hostage unveils the story of Asad, Hamal, Shahin and Fahdah, who each has their own motive for joining the war in terror. Asad, the appointed leader of the group, manages the team with strict and clear direction, taking orders behind the scenes from Al-Saqri whose motives are unclear. Asad shows one weakness, the affection for fellow terrorist Fahdah, a soft spoken young Arab woman. Asad and Fahdah develop an adoration for each other, despite the disapproval from Fahdah's brother Hamal whose anger from the overall situation escalates throughout the story. Meanwhile Shahin, the fourth terrorist, and prisoner Sergeant Donald Young begin to form a bond as they share stories about family, faith and love. Although the plan of gaining explicit media coverage after leaking the hostage tapes, the U.S. government shows no cooperation in response to the demands on Guantanamo Bay. The terrorists go through extreme measures in attempts to persuade the government one final time. But before their plan is executed, unforeseen circumstances arise that force them to think and act in a different direction...",
#   'languages': ['English'],
#   'released': datetime.datetime(2015, 3, 26, 0, 0),
#   'directors': ['Mounir Chakor'],
#   'writers': ['Mounir Chakor'],
#   'awards': {'wins': 1, 'nominations': 0, 'text': '1 win.'},
#   'lastupdated': '2015-08-24 00:19:40.167000000',
#   'year': 2015,
#   'imdb': {'rating': '', 'votes': '', 'id': 3468612},
#   'countries': ['USA'],
#   'type': 'movie'},
#  {'_id': ObjectId('573a13eef29313caabdd676a'),
#   'plot': "In search of the lucrative matsutake mushroom, two former soldiers discover the means to gradually heal their wounds of war. Roger, a self-described 'fall-down drunk' and sniper in Vietnam,...",
#   'genres': ['Documentary', 'Family', 'War'],
#   'runtime': 78,
#   'cast': ['Joe Berry', 'Uncle Bob', 'Sam Doungaphay', 'Sokmakara Hang'],
#   'num_mflix_comments': 1,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTY2NDYzNDcyOF5BMl5BanBnXkFtZTgwNTAxNjkyMjE@._V1_SY1000_SX677_AL_.jpg',
#   'title': 'The Last Season',
#   'fullplot': "In search of the lucrative matsutake mushroom, two former soldiers discover the means to gradually heal their wounds of war. Roger, a self-described 'fall-down drunk' and sniper in Vietnam, and Kouy, a Cambodian refugee who fought the Khmer Rouge, bonded in the bustling tent-city known as Mushroom Camp, which pops up each autumn in the Oregon woods. Their friendship became an adoptive family; according to a Cambodian custom, if you lose your family like Kouy, you must rebuilt it anew. Now, however, this new family could be lost. Roger's health is declining and trauma flashbacks rack his mind; Kouy gently aids his family before the snow falls and the hunting season ends, signaling his time to leave.",
#   'languages': ['English'],
#   'released': datetime.datetime(2014, 4, 25, 0, 0),
#   'directors': ['Sara Dosa'],
#   'awards': {'wins': 1, 'nominations': 1, 'text': '1 win & 1 nomination.'},
#   'lastupdated': '2014-09-20 04:04:23.547000000',
#   'year': 2014,
#   'imdb': {'rating': '', 'votes': '', 'id': 3593932},
#   'countries': ['USA'],
#   'type': 'movie'},
#  {'_id': ObjectId('573a139ff29313caabd003c4'),
#   'plot': 'The story of Easy Company of the US Army 101st Airborne division and their mission in WWII Europe from Operation Overlord through V-J Day.',
#   'genres': ['Action', 'Drama', 'History'],
#   'runtime': 705,
#   'cast': ['Scott Grimes', 'Matthew Leitch', 'Damian Lewis', 'Ron Livingston'],
#   'num_mflix_comments': 0,
#   'poster': 'https://m.media-amazon.com/images/M/MV5BMTI3ODc2ODc0M15BMl5BanBnXkFtZTYwMjgzNjc3._V1_SY1000_SX677_AL_.jpg',
#   'title': 'Band of Brothers',
#   'fullplot': 'This is the story of "E" Easy Company, 506th Regiment of the 101st Airborne Division from their initial training starting in 1942 to the end of World War II. They parachuted behind enemy lines in the early hours of D-Day in support of the landings at Utah beach, participated in the liberation of Carentan and again parachuted into action during Operation Market Garden. They also liberated a concentration camp and were the first to enter Hitler\'s mountain retreat in Berchtesgaden. A fascinating tale of comradeship that is, in the end, a tale of ordinary men who did extraordinary things.',
#   'languages': ['English', 'Dutch', 'French', 'German', 'Lithuanian'],
#   'released': datetime.datetime(2001, 9, 9, 0, 0),
#   'rated': 'TV-MA',
#   'awards': {'wins': 34,
#    'nominations': 24,
#    'text': 'Won 1 Golden Globe. Another 33 wins & 24 nominations.'},
#   'lastupdated': '2015-08-31 00:04:34.187000000',
#   'year': 2001,
#   'imdb': {'rating': 9.6, 'votes': 183802, 'id': 185906},
#   'countries': ['UK', 'USA'],
#   'type': 'series',
#   'tomatoes': {'viewer': {'rating': 2.0, 'numReviews': 15},
#    'dvd': datetime.datetime(2009, 3, 17, 0, 0),
#    'lastUpdated': datetime.datetime(2015, 9, 12, 17, 15, 33)}}]
